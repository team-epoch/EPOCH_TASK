# %% [markdown]
# **뉴스데이터 감성 분석**
#
#
# **Task_1: 데이터 출처**
#
# DACON, 2023 NH 투자증권 빅데이터 경진대회, “블룸버그, 나스닥과 함께 세계속으로!"
#
# https://dacon.io/competitions/official/236145/overview/description
#
#
# **TASK 2. 기초 통계 확인**
#
#
# **TASK 3. 분석 목적/인사이트 설명**
#
# 1. 분석 목적: 금융 도메인에서 숨겨진 인사이트 탐색 AI 시스템을 만들기 위해, 우선적으로 뉴스데이터 감성 분석을 통한 전망 분석
#
# 2. 인사이트:
# - 반복성 지표: 동일 제목(예, 배당 관련 뉴스)이 여러 번 등장. 이는 뉴스 콘텐츠의 중복 또는 인기 주제의 반복 보도를 시사함
# - 주요 주제 집중: ctgy_cfc_ifo에서 'Stocks,Investing', 'Markets' 등 주식 및 시장 관련 범주가 압도적. 투자 및 금융 시장 뉴스가 주류를 이룸
# - 다양성 및 긴 꼬리: 소수 등장 범주들이 다수 존재, 이는 특정 소주제의 다양성 또는 전문 분야 세분화를 반영
# - 분석 및 활용 제언:
# 콘텐츠 중복 여부 및 영향 분석 필요
# 핵심 뉴스 주제와 니치 주제 간 차별화 전략 마련
# 투자자 관심 트렌드 분석 및 관련 인사이트 도출 가능

# %% [markdown]
# ## 라이브러리 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/3rd/pj')
# Out:
# Mounted at /content/drive

# %%
#기본
import numpy as np #수학적 계산
import pandas as pd #데이터프레임
import matplotlib.pyplot as plt #시각화
import seaborn as sns #시각화
import itertools #반복문 유틸리티
import time
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##1. 데이터셋 불러오기

# %% [markdown]
# ###1.1 월별 뉴스 데이터

# %%
jan = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_RSS_IFO_202301.csv', encoding = 'cp949')
feb = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_RSS_IFO_202302.csv', encoding = 'cp949')
mar = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_RSS_IFO_202303.csv', encoding = 'cp949')
apr = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_RSS_IFO_202304.csv', encoding = 'cp949')
may = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_RSS_IFO_202305.csv', encoding = 'cp949')
jun = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_RSS_IFO_202306.csv', encoding = 'cp949')
jul = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_RSS_IFO_202307.csv', encoding = 'cp949')
aug = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_RSS_IFO_202308.csv', encoding = 'cp949')

# %% [markdown]
# ###1.2 주가 데이터

# %%
price = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_DT_FC_STK_QUT.csv', encoding = 'cp949')

# %% [markdown]
# ##2. 전처리

# %%
# 모든 열이 중복되는 행 제거
jan.drop_duplicates(inplace = True, ignore_index =  True)
feb.drop_duplicates(inplace = True, ignore_index =  True)
mar.drop_duplicates(inplace = True, ignore_index =  True)
apr.drop_duplicates(inplace = True, ignore_index =  True)
may.drop_duplicates(inplace = True, ignore_index =  True)
jun.drop_duplicates(inplace = True, ignore_index =  True)
jul.drop_duplicates(inplace = True, ignore_index =  True)
aug.drop_duplicates(inplace = True, ignore_index =  True)

# %%
# 날짜 열을 정수 형식에서 날짜 형식으로 변환
jan['rgs_dt'] = pd.to_datetime(jan['rgs_dt'].astype(str), format = '%Y%m%d')
feb['rgs_dt'] = pd.to_datetime(feb['rgs_dt'].astype(str), format = '%Y%m%d')
mar['rgs_dt'] = pd.to_datetime(mar['rgs_dt'].astype(str), format = '%Y%m%d')
apr['rgs_dt'] = pd.to_datetime(apr['rgs_dt'].astype(str), format = '%Y%m%d')
may['rgs_dt'] = pd.to_datetime(may['rgs_dt'].astype(str), format = '%Y%m%d')
jun['rgs_dt'] = pd.to_datetime(jun['rgs_dt'].astype(str), format = '%Y%m%d')
jul['rgs_dt'] = pd.to_datetime(jul['rgs_dt'].astype(str), format = '%Y%m%d')
aug['rgs_dt'] = pd.to_datetime(aug['rgs_dt'].astype(str), format = '%Y%m%d')
price['trd_dt'] = pd.to_datetime(price['trd_dt'].astype(str), format = '%Y%m%d')

# %%
# 뉴스 데이터 형태 보기
jan.head()
# Out:
#       rgs_dt tck_iem_cd                                            til_ifo  \
# 0 2023-01-02        NGS  Hoak & Co. Urges NGS Board to Halt CEO Search ...
# 1 2023-01-02        PFX  Here's Why PhenixFIN (PFX) is Poised for a Tur...
# 2 2023-01-02        TYG     My Advice? Sell These 2 Dividend Funds in 2023
# 3 2023-01-02       NVIV  France's InVivo to buy one of the world's olde...
# 4 2023-01-02        FEN     My Advice? Sell These 2 Dividend Funds in 2023
#
#                      ctgy_cfc_ifo     mdi_ifo  \
# 0                       Investing      Fintel
# 1                Stocks,Investing       Zacks
# 2                  Markets,Stocks  BNK Invest
# 3  Commodities,BioTech,US Markets     Reuters
# 4                  Markets,Stocks  BNK Invest
#
#                                         news_smy_ifo rld_ose_iem_tck_cd  \
# 0  Fintel reports that Hoak Public Equities, LP, ...                NGS
# 1  PhenixFIN (PFX) has been beaten down lately wi...                PFX
# 2  There's a disconnect setting up in the energy ...        TYG,TYG,FEN
# 3  Malteries Soufflet, a branch of French agribus...               NVIV
# 4  There's a disconnect setting up in the energy ...        TYG,TYG,FEN
#
#                                              url_ifo
# 0  https://www.nasdaq.com/articles/hoak-co.-urges...
# 1  https://www.nasdaq.com/articles/heres-why-phen...
# 2  https://www.nasdaq.com/articles/my-advice-sell...
# 3  https://www.nasdaq.com/articles/frances-invivo...
# 4  https://www.nasdaq.com/articles/my-advice-sell...

# %%
# 뉴스 데이터의 url_ifo 컬럼이 필요 없다고 판단하여 삭제
jan.drop('url_ifo', axis = 1, inplace = True)
feb.drop('url_ifo', axis = 1, inplace = True)
mar.drop('url_ifo', axis = 1, inplace = True)
apr.drop('url_ifo', axis = 1, inplace = True)
may.drop('url_ifo', axis = 1, inplace = True)
jun.drop('url_ifo', axis = 1, inplace = True)
jul.drop('url_ifo', axis = 1, inplace = True)
aug.drop('url_ifo', axis = 1, inplace = True)

# %%
# 뉴스 데이터를 하나로 결합
news = pd.concat([jan, feb, mar, apr, may, jun, jul, aug], ignore_index = True)
news.head()
# Out:
#       rgs_dt tck_iem_cd                                            til_ifo  \
# 0 2023-01-02        NGS  Hoak & Co. Urges NGS Board to Halt CEO Search ...
# 1 2023-01-02        PFX  Here's Why PhenixFIN (PFX) is Poised for a Tur...
# 2 2023-01-02        TYG     My Advice? Sell These 2 Dividend Funds in 2023
# 3 2023-01-02       NVIV  France's InVivo to buy one of the world's olde...
# 4 2023-01-02        FEN     My Advice? Sell These 2 Dividend Funds in 2023
#
#                      ctgy_cfc_ifo     mdi_ifo  \
# 0                       Investing      Fintel
# 1                Stocks,Investing       Zacks
# 2                  Markets,Stocks  BNK Invest
# 3  Commodities,BioTech,US Markets     Reuters
# 4                  Markets,Stocks  BNK Invest
#
#                                         news_smy_ifo rld_ose_iem_tck_cd
# 0  Fintel reports that Hoak Public Equities, LP, ...                NGS
# 1  PhenixFIN (PFX) has been beaten down lately wi...                PFX
# 2  There's a disconnect setting up in the energy ...        TYG,TYG,FEN
# 3  Malteries Soufflet, a branch of French agribus...               NVIV
# 4  There's a disconnect setting up in the energy ...        TYG,TYG,FEN

# %%
# 주가 데이터에서 시가, 저가, 고가, 누적거래수량, 매도체결합계수량, 매수체결합계수량 삭제
price.drop(['gts_iem_ong_pr', 'gts_iem_hi_pr', 'gts_iem_low_pr', 'gts_acl_trd_qty', 'gts_sll_cns_sum_qty', 'gts_byn_cns_sum_qty'], axis = 1, inplace = True)

# %%
# 영업일 목록 만들기
from datetime import datetime
business_days = list(price['trd_dt'].dt.strftime('%Y-%m-%d').unique())
business_days = [datetime.strptime(bday, '%Y-%m-%d') for bday in business_days]
business_days[:20]

# 뉴스 기사 나온 날 목록 만들기
news_days = list(news['rgs_dt'].dt.strftime('%Y-%m-%d').unique())
news_days = [datetime.strptime(nday, '%Y-%m-%d') for nday in news_days]
news_days[:25]

# merge된 데이터에서 안 헷갈리게 주가 데이터에 영업일 열 추가
price['business_days'] = price['trd_dt']

# %%
# 뉴스 데이터 티커 개수가 주가 데이터 티커 개수보다 많음
print('뉴스 데이터 티커 개수:', news['tck_iem_cd'].nunique())
print('주가 데이터 티커 개수:', price['tck_iem_cd'].nunique())
# Out:
# 뉴스 데이터 티커 개수: 5976
# 주가 데이터 티커 개수: 2743

# %%
# 종목 데이터 티커 개수는 주가 데이터 티커 개수와 동일
tck = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd/pj/NASDAQ_FC_STK_IEM_IFO.csv', encoding = 'cp949')
print('종목 데이터 티커 개수:', tck['tck_iem_cd'].nunique())
# Out:
# 종목 데이터 티커 개수: 2743

# %%
# 뉴스 데이터에는 있지만, 주가 데이터에는 없는 티커를 삭제한 뉴스 데이터를 이용
price_tck_lst = list(price['tck_iem_cd'].unique())

news_2 = news[news['tck_iem_cd'].isin(price_tck_lst)]
news_2.head(30)
# Out:
#        rgs_dt tck_iem_cd                                            til_ifo  \
# 3  2023-01-02       NVIV  France's InVivo to buy one of the world's olde...
# 5  2023-01-02       NUVL  Are Medical Stocks Lagging  DICE Therapeutics ...
# 7  2023-01-02       SCPH  scPharmaceuticals, Inc. (SCPH) Is a Great Choi...
# 9  2023-01-02       IVVD   Invivyd, Inc. (IVVD) Upgraded to Buy: Here's Why
# 11 2023-01-02      BELFB  Is Bel Fuse (BELFB) Stock Outpacing Its Comput...
# 12 2023-01-02       NUVL  Are Medical Stocks Lagging  DICE Therapeutics ...
# 14 2023-01-03       NRXP  Health Care Sector Update for 01/03/2023: XLV,...
# 15 2023-01-03       SILO   Pre-market Movers: GRRR, MNPR, KALA, SONX, PEGY…
# 16 2023-01-03       SIDU  Technology Sector Update for 01/03/2023: SIDU,...
# 17 2023-01-03       SIDU  Technology Sector Update for 01/03/2023: IDCC,...
# 19 2023-01-03         SY  So-Young Increases Aggregate Value Of Share Re...
# 21 2023-01-03        NVX  Australian shares commence 2023 lower; gold st...
# 26 2023-01-03      RTLPO  The Necessity Retail REIT Announces Common Sto...
# 28 2023-01-03       PEGY   Pre-market Movers: GRRR, MNPR, KALA, SONX, PEGY…
# 29 2023-01-03       PROF  Recent Price Trend in Profound Medical (PROF) ...
# 30 2023-01-03       RDHL  RedHill Biopharma Reports Positive Data From P...
# 31 2023-01-03       ASLN  ASLAN, Thermo Fisher Join To Manufacture High ...
# 33 2023-01-03       ATAT  Sore Thumb Indicator: 3 Chinese ADRs Pass the ...
# 34 2023-01-03      OZKAP  Bank OZK Announces Increase to Quarterly Commo...
# 35 2023-01-03       TCPC              New Strong Buy Stocks for January 3rd
# 36 2023-01-03       SVRA      Tuesday 1/3 Insider Buying Report: SVRA, THRX
# 37 2023-01-03       SWKH  Financial Sector Update for 01/03/2023: RIOT, ...
# 38 2023-01-03       SWKH  Financial Sector Update for 01/03/2023: FRME,S...
# 39 2023-01-03       SWKH  SWK Holdings Appoints Jody Staggs Chief Execut...
# 40 2023-01-03         SY  Health Care Sector Update for 01/03/2023: XLV,...
# 41 2023-01-03       THRX      Tuesday 1/3 Insider Buying Report: SVRA, THRX
# 44 2023-01-03       TXMD  Health Care Sector Update for 01/03/2023: XLV,...
# 45 2023-01-03       TXMD  TherapeuticsMD Grants Mayne Pharma License To ...
# 50 2023-01-03       MGIC  Is DecisionPoint Systems  (DPSI) Stock Underva...
# 52 2023-01-03       MDXG               MiMedx Appoints Ricci Whitlow As COO
#
#                       ctgy_cfc_ifo      mdi_ifo  \
# 3   Commodities,BioTech,US Markets      Reuters
# 5                 Stocks,Investing        Zacks
# 7                 Stocks,Investing        Zacks
# 9                 Stocks,Investing        Zacks
# 11                Stocks,Investing        Zacks
# 12                Stocks,Investing        Zacks
# 14                      US Markets  MTNewswires
# 15                         Markets      RTTNews
# 16                      Technology  MTNewswires
# 17                      Technology  MTNewswires
# 19                         Markets      RTTNews
# 21                               _      Reuters
# 26                               _            _
# 28                         Markets      RTTNews
# 29                Stocks,Investing        Zacks
# 30                         Markets      RTTNews
# 31                         Markets      RTTNews
# 33                Investing,Stocks        Zacks
# 34                               _            _
# 35                      Technology        Zacks
# 36                  Markets,Stocks   BNK Invest
# 37                         Banking  MTNewswires
# 38                         Banking  MTNewswires
# 39                         Markets      RTTNews
# 40                      US Markets  MTNewswires
# 41                  Markets,Stocks   BNK Invest
# 44                      US Markets  MTNewswires
# 45                         Markets      RTTNews
# 50                Stocks,Investing        Zacks
# 52                         Markets      RTTNews
#
#                                          news_smy_ifo  \
# 3   Malteries Soufflet, a branch of French agribus...
# 5   Investors interested in Medical stocks should ...
# 7   "When it comes to short-term investing or trad...
# 9   Investors might want to bet on Invivyd, Inc. (...
# 11  For those looking to find strong Computer and ...
# 12  Investors interested in Medical stocks should ...
# 14  Health care stocks were trending higher pre-be...
# 15  (RTTNews) - The following are some of the stoc...
# 16  Technology stocks were declining on Tuesday, w...
# 17  Technology stocks pared a portion of their ear...
# 19  (RTTNews) - So-Young International Inc. (SY) a...
# 21  Australian shares fell on the first trading se...
# 26  --The Necessity Retail REIT, Inc. announced to...
# 28  (RTTNews) - The following are some of the stoc...
# 29  "Most of us have heard the dictum ""the trend ...
# 30  (RTTNews) - RedHill Biopharma Ltd. (RDHL) anno...
# 31  (RTTNews) - ASLAN Pharmaceuticals (ASLN) and T...
# 33  With thousands of stocks open for trading each...
# 34  --Bank OZK announced its Board of Directors de...
# 35  Here are five stocks added to the Zacks Rank #...
# 36  Bargain hunters are wise to pay careful attent...
# 37  Financial stocks turned narrowly higher again ...
# 38  Financial stocks have turned narrowly lower in...
# 39  (RTTNews) - SWK Holdings Corp. (SWKH) Tuesday ...
# 40  Health care stocks were trending higher pre-be...
# 41  Bargain hunters are wise to pay careful attent...
# 44  Health care stocks were trending higher pre-be...
# 45  (RTTNews) - TherapeuticsMD Inc. (TXMD) Tuesday...
# 50  Here at Zacks, we focus on our proven ranking ...
# 52  (RTTNews) - MiMedx Group, Inc. (MDXG), a biome...
#
#                                    rld_ose_iem_tck_cd
# 3                                                NVIV
# 5                                           DICE,NUVL
# 7                                                SCPH
# 9                                                IVVD
# 11                                         BELFB,PERI
# 12                                               NUVL
# 14                           XLV,XLV,VHT,TXMD,SY,NRXP
# 15  AMAM,AMAM,EVH,GRRR,KALA,KEP,MNPR,PBR,PEGY,RMED...
# 16                                   SIDU,SIDU,TDY,IQ
# 17                              IDCC,IDCC,SIDU,TDY,IQ
# 19                                                 SY
# 21                                            NVX,RIO
# 26                                    RTLPO,RTLPP,RTL
# 28  AMAM,AMAM,EVH,GRRR,KALA,KEP,MNPR,PBR,PEGY,RMED...
# 29                                               PROF
# 30                                               RDHL
# 31                                      ASLN,ASLN,TMO
# 33         YUM,MOMO,KWEB,BILI,PDD,QFIN,COIN,HOOD,ATAT
# 34                                          OZKAP,OZK
# 35                            CECO,TCPC,LPG,RNGR,BAND
# 36                                     SVRA,SVRA,THRX
# 37                            RIOT,RIOT,FRME,SRG,SWKH
# 38                                 FRME,FRME,SRG,SWKH
# 39                                               SWKH
# 40                           XLV,XLV,VHT,TXMD,SY,NRXP
# 41                                     SVRA,SVRA,THRX
# 44                           XLV,XLV,VHT,TXMD,SY,NRXP
# 45                                               TXMD
# 50                                          DPSI,MGIC
# 52                                               MDXG

# %%
import pandas as pd
from datetime import datetime

# 주말 뉴스의 날짜를 다음 영업일로 조정
adj_business_days2 = []
for nday in news_2['rgs_dt']:
    if nday in business_days:
        adj_business_days2.append(nday)
    else:
        filtered = [d for d in business_days if d > nday]
        adj_business_days2.append(min(filtered) if filtered else None)

news_2['trd_dt'] = adj_business_days2
news_2.reset_index(drop=True, inplace=True)

# 결측 trd_dt는 2023-08-31로 대체
def replace_nat(row):
    if pd.isna(row['trd_dt']):
        row['trd_dt'] = datetime(2023, 8, 31)
    return row

news_2 = news_2.apply(replace_nat, axis=1)

# 주가 데이터와 뉴스 데이터를 trd_dt와 tck_iem_cd 기준으로 병합
news_price_merge = pd.merge(price, news_2, how='left', on=['trd_dt', 'tck_iem_cd'])

# 병합 검증: 2023-01-03의 티커 목록 및 해당 행 확인
unique_cd = news_2[news_2['trd_dt'] == pd.Timestamp('2023-01-03')]['tck_iem_cd'].unique()
print(unique_cd)
print('개수:', len(unique_cd))

merge_check = news_price_merge[(news_price_merge['trd_dt'] == pd.Timestamp('2023-01-03')) &
                               (news_price_merge['tck_iem_cd'].isin(unique_cd))]
print(merge_check)
print('개수:', len(merge_check))

# 중복 행 제거 및 불필요한 business_days 컬럼 삭제
drop_cols = ['trd_dt', 'tck_iem_cd', 'gts_iem_end_pr', 'business_days',
             'rgs_dt', 'til_ifo', 'ctgy_cfc_ifo', 'mdi_ifo', 'news_smy_ifo']
news_price_merge.drop_duplicates(subset=drop_cols, inplace=True, ignore_index=True)

if 'business_days' in news_price_merge.columns:
    news_price_merge.drop('business_days', axis=1, inplace=True)

# news_price_merge.to_csv('news_price_merge.csv', index=False)
# Out:
# ['NVIV' 'NUVL' 'SCPH' 'IVVD' 'BELFB' 'NRXP' 'SILO' 'SIDU' 'SY' 'NVX'
#  'RTLPO' 'PEGY' 'PROF' 'RDHL' 'ASLN' 'ATAT' 'OZKAP' 'TCPC' 'SVRA' 'SWKH'
#  'THRX' 'TXMD' 'MGIC' 'MDXG' 'MDVL' 'ADTX' 'AIRG' 'BLZE' 'LEDS' 'BIOX'
#  'BIVI' 'BNR' 'JUPW' 'JSPR' 'CMMB' 'CYN' 'ELBM' 'HSTM' 'EVAX' 'EZFL' 'GEG'
#  'GRRR' 'CTKB']
# 개수: 43
#          trd_dt tck_iem_cd  gts_iem_end_pr business_days     rgs_dt  \
# 9    2023-01-03       SILO          3.0700    2023-01-03 2023-01-03
# 10   2023-01-03       SILO          3.0700    2023-01-03 2023-01-03
# 179  2023-01-03        BNR          2.1600    2023-01-03 2023-01-03
# 230  2023-01-03        NVX          3.9000    2023-01-03 2023-01-03
# 275  2023-01-03       SCPH          6.6200    2023-01-03 2023-01-02
# 311  2023-01-03       AIRG          6.8000    2023-01-03 2023-01-03
# 361  2023-01-03       ELBM          1.8400    2023-01-03 2023-01-03
# 447  2023-01-03       BIVI          6.1700    2023-01-03 2023-01-03
# 469  2023-01-03       GRRR          9.6300    2023-01-03 2023-01-03
# 470  2023-01-03       GRRR          9.6300    2023-01-03 2023-01-03
# 471  2023-01-03       MGIC         16.1800    2023-01-03 2023-01-03
# 647  2023-01-03       CMMB          2.9400    2023-01-03 2023-01-03
# 682  2023-01-03       BLZE          6.1400    2023-01-03 2023-01-03
# 706  2023-01-03       ASLN          2.1758    2023-01-03 2023-01-03
# 734  2023-01-03      BELFB         32.7500    2023-01-03 2023-01-02
# 737  2023-01-03       THRX          5.2100    2023-01-03 2023-01-03
# 748  2023-01-03       MDVL         14.5950    2023-01-03 2023-01-03
# 834  2023-01-03       RDHL          0.1770    2023-01-03 2023-01-03
# 891  2023-01-03       JUPW          0.7701    2023-01-03 2023-01-03
# 920  2023-01-03       LEDS          1.8200    2023-01-03 2023-01-03
# 952  2023-01-03       TCPC         13.0300    2023-01-03 2023-01-03
# 1021 2023-01-03       SWKH         18.0400    2023-01-03 2023-01-03
# 1022 2023-01-03       SWKH         18.0400    2023-01-03 2023-01-03
# 1023 2023-01-03       SWKH         18.0400    2023-01-03 2023-01-03
# 1052 2023-01-03       ADTX         63.2000    2023-01-03 2023-01-03
# 1053 2023-01-03       ADTX         63.2000    2023-01-03 2023-01-03
# 1110 2023-01-03       IVVD          1.5500    2023-01-03 2023-01-02
# 1115 2023-01-03       JSPR          2.7400    2023-01-03 2023-01-03
# 1246 2023-01-03       HSTM         24.6700    2023-01-03 2023-01-03
# 1247 2023-01-03       HSTM         24.6700    2023-01-03 2023-01-03
# 1293 2023-01-03       EVAX          1.7400    2023-01-03 2023-01-03
# 1475 2023-01-03        GEG          2.1100    2023-01-03 2023-01-03
# 1575 2023-01-03      OZKAP         16.0500    2023-01-03 2023-01-03
# 1688 2023-01-03       NRXP          1.2100    2023-01-03 2023-01-03
# 1725 2023-01-03       NVIV          2.2900    2023-01-03 2023-01-02
# 1751 2023-01-03       ATAT         19.3300    2023-01-03 2023-01-03
# 1791 2023-01-03       CTKB         10.1200    2023-01-03 2023-01-03
# 1928 2023-01-03       PROF         11.0500    2023-01-03 2023-01-03
# 2026 2023-01-03       TXMD          6.2500    2023-01-03 2023-01-03
# 2027 2023-01-03       TXMD          6.2500    2023-01-03 2023-01-03
# 2068 2023-01-03      RTLPO         20.5200    2023-01-03 2023-01-03
# 2167 2023-01-03       MDXG          2.9700    2023-01-03 2023-01-03
# 2326 2023-01-03       PEGY          2.2800    2023-01-03 2023-01-03
# 2327 2023-01-03       PEGY          2.2800    2023-01-03 2023-01-03
# 2493 2023-01-03        CYN          0.6600    2023-01-03 2023-01-03
# 2520 2023-01-03       EZFL          2.2744    2023-01-03 2023-01-03
# 2521 2023-01-03       EZFL          2.2744    2023-01-03 2023-01-03
# 2529 2023-01-03       SIDU          1.0200    2023-01-03 2023-01-03
# 2530 2023-01-03       SIDU          1.0200    2023-01-03 2023-01-03
# 2567 2023-01-03       NUVL         28.9700    2023-01-03 2023-01-02
# 2568 2023-01-03       NUVL         28.9700    2023-01-03 2023-01-02
# 2636 2023-01-03       BIOX         11.8100    2023-01-03 2023-01-03
# 2655 2023-01-03       SVRA          1.6000    2023-01-03 2023-01-03
# 2735 2023-01-03         SY          1.4500    2023-01-03 2023-01-03
# 2736 2023-01-03         SY          1.4500    2023-01-03 2023-01-03
#
#                                                 til_ifo  \
# 9      Pre-market Movers: GRRR, MNPR, KALA, SONX, PEGY…
# 10     Pre-market Movers: GRRR, MNPR, KALA, SONX, PEGY…
# 179   Burning Rock Says FDA Grants Breakthrough Devi...
# 230   Australian shares commence 2023 lower; gold st...
# 275   scPharmaceuticals, Inc. (SCPH) Is a Great Choi...
# 311   Strength Seen in Airgain (AIRG): Can Its 6.4% ...
# 361   Tuesday Sector Leaders: Education & Training S...
# 447   Beat the Market Like Zacks: JPMorgan Chase, Or...
# 469    Pre-market Movers: GRRR, MNPR, KALA, SONX, PEGY…
# 470    Pre-market Movers: GRRR, MNPR, KALA, SONX, PEGY…
# 471   Is DecisionPoint Systems  (DPSI) Stock Underva...
# 647   Chemomab Jumps 35% After Reporting NASH Trial ...
# 682   Backblaze, Inc. (BLZE) Surges 7.1%: Is This an...
# 706   ASLAN, Thermo Fisher Join To Manufacture High ...
# 734   Is Bel Fuse (BELFB) Stock Outpacing Its Comput...
# 737       Tuesday 1/3 Insider Buying Report: SVRA, THRX
# 748   Why Hold Strategy is Apt for Centene (CNC) Sto...
# 834   RedHill Biopharma Reports Positive Data From P...
# 891       Tuesday 1/3 Insider Buying Report: AKAM, JUPW
# 920               SemiLEDs Q1 Loss Narrows Sequentially
# 952               New Strong Buy Stocks for January 3rd
# 1021  Financial Sector Update for 01/03/2023: RIOT, ...
# 1022  Financial Sector Update for 01/03/2023: FRME,S...
# 1023  SWK Holdings Appoints Jody Staggs Chief Execut...
# 1052  Health Care Sector Update for 01/03/2023: HCM,...
# 1053  Health Care Sector Update for 01/03/2023: HSTM...
# 1110   Invivyd, Inc. (IVVD) Upgraded to Buy: Here's Why
# 1115  Jasper Spikes On Positive Data For Briquilimab...
# 1246  Health Care Sector Update for 01/03/2023: HSTM...
# 1247  Health Care Sector Update for 01/03/2023: HCM,...
# 1293  Evaxion Biotech Gets FDA Approval To Proceed W...
# 1475  Great Elm Group Sells Durable Medical Equipmen...
# 1575  Bank OZK Announces Increase to Quarterly Commo...
# 1688  Health Care Sector Update for 01/03/2023: XLV,...
# 1725  France's InVivo to buy one of the world's olde...
# 1751  Sore Thumb Indicator: 3 Chinese ADRs Pass the ...
# 1791      Relative Strength Alert For Cytek BioSciences
# 1928  Recent Price Trend in Profound Medical (PROF) ...
# 2026  Health Care Sector Update for 01/03/2023: XLV,...
# 2027  TherapeuticsMD Grants Mayne Pharma License To ...
# 2068  The Necessity Retail REIT Announces Common Sto...
# 2167               MiMedx Appoints Ricci Whitlow As COO
# 2326   Pre-market Movers: GRRR, MNPR, KALA, SONX, PEGY…
# 2327   Pre-market Movers: GRRR, MNPR, KALA, SONX, PEGY…
# 2493  Technology Sector Update for 01/03/2023: XLK, ...
# 2520  Energy Sector Update for 01/03/2023: TRGP,BX,W...
# 2521  Energy Sector Update for 01/03/2023: WFRD, WHD...
# 2529  Technology Sector Update for 01/03/2023: SIDU,...
# 2530  Technology Sector Update for 01/03/2023: IDCC,...
# 2567  Are Medical Stocks Lagging  DICE Therapeutics ...
# 2568  Are Medical Stocks Lagging  DICE Therapeutics ...
# 2636  Consumer Sector Update for 01/03/2023: BIOX,SA...
# 2655      Tuesday 1/3 Insider Buying Report: SVRA, THRX
# 2735  So-Young Increases Aggregate Value Of Share Re...
# 2736  Health Care Sector Update for 01/03/2023: XLV,...
#
#                         ctgy_cfc_ifo      mdi_ifo  \
# 9                            Markets      RTTNews
# 10                           Markets      RTTNews
# 179                          Markets      RTTNews
# 230                                _      Reuters
# 275                 Stocks,Investing        Zacks
# 311                 Stocks,Investing        Zacks
# 361                   Markets,Stocks   BNK Invest
# 447                 Stocks,Investing        Zacks
# 469                          Markets      RTTNews
# 470                          Markets      RTTNews
# 471                 Stocks,Investing        Zacks
# 647                          Markets      RTTNews
# 682                 Stocks,Investing        Zacks
# 706                          Markets      RTTNews
# 734                 Stocks,Investing        Zacks
# 737                   Markets,Stocks   BNK Invest
# 748                 Stocks,Investing        Zacks
# 834                          Markets      RTTNews
# 891                   Markets,Stocks   BNK Invest
# 920                          Markets      RTTNews
# 952                       Technology        Zacks
# 1021                         Banking  MTNewswires
# 1022                         Banking  MTNewswires
# 1023                         Markets      RTTNews
# 1052                      US Markets  MTNewswires
# 1053                      US Markets  MTNewswires
# 1110                Stocks,Investing        Zacks
# 1115                         Markets      RTTNews
# 1246                      US Markets  MTNewswires
# 1247                      US Markets  MTNewswires
# 1293                         Markets      RTTNews
# 1475                         Markets      RTTNews
# 1575                               _            _
# 1688                      US Markets  MTNewswires
# 1725  Commodities,BioTech,US Markets      Reuters
# 1751                Investing,Stocks        Zacks
# 1791                  Markets,Stocks   BNK Invest
# 1928                Stocks,Investing        Zacks
# 2026                      US Markets  MTNewswires
# 2027                         Markets      RTTNews
# 2068                               _            _
# 2167                         Markets      RTTNews
# 2326                         Markets      RTTNews
# 2327                         Markets      RTTNews
# 2493                      Technology  MTNewswires
# 2520                          Energy  MTNewswires
# 2521                          Energy  MTNewswires
# 2529                      Technology  MTNewswires
# 2530                      Technology  MTNewswires
# 2567                Stocks,Investing        Zacks
# 2568                Stocks,Investing        Zacks
# 2636                         Markets  MTNewswires
# 2655                  Markets,Stocks   BNK Invest
# 2735                         Markets      RTTNews
# 2736                      US Markets  MTNewswires
#
#                                            news_smy_ifo  \
# 9     (RTTNews) - The following are some of the stoc...
# 10    (RTTNews) - The following are some of the stoc...
# 179   (RTTNews) - Burning Rock (BNR), a company focu...
# 230   Australian shares fell on the first trading se...
# 275   "When it comes to short-term investing or trad...
# 311   Airgain (AIRG) shares ended the last trading s...
# 361   In trading on Tuesday, education &amp; trainin...
# 447   The three most widely followed indexes decline...
# 469   (RTTNews) - The following are some of the stoc...
# 470   (RTTNews) - The following are some of the stoc...
# 471   Here at Zacks, we focus on our proven ranking ...
# 647   (RTTNews) - Chemomab Therapeutics, Ltd. (CMMB)...
# 682   Backblaze, Inc. (BLZE) shares soared 7.1% in t...
# 706   (RTTNews) - ASLAN Pharmaceuticals (ASLN) and T...
# 734   For those looking to find strong Computer and ...
# 737   Bargain hunters are wise to pay careful attent...
# 748   Centene Corporation CNC is expected to remain ...
# 834   (RTTNews) - RedHill Biopharma Ltd. (RDHL) anno...
# 891   As the saying goes, there are many possible re...
# 920   (RTTNews) - SemiLEDs Corp. (LEDS), a Taiwanese...
# 952   Here are five stocks added to the Zacks Rank #...
# 1021  Financial stocks turned narrowly higher again ...
# 1022  Financial stocks have turned narrowly lower in...
# 1023  (RTTNews) - SWK Holdings Corp. (SWKH) Tuesday ...
# 1052  Health care stocks were ending mostly lower Tu...
# 1053  Health care stocks were mostly lower this Tues...
# 1110  Investors might want to bet on Invivyd, Inc. (...
# 1115  (RTTNews) - Jasper Therapeutics, Inc. (JSPR) s...
# 1246  Health care stocks were mostly lower this Tues...
# 1247  Health care stocks were ending mostly lower Tu...
# 1293  (RTTNews) - Biotech company Evaxion Biotech A/...
# 1475  (RTTNews) - Shares of Great Elm Group, Inc. (G...
# 1575  --Bank OZK announced its Board of Directors de...
# 1688  Health care stocks were trending higher pre-be...
# 1725  Malteries Soufflet, a branch of French agribus...
# 1751  With thousands of stocks open for trading each...
# 1791  Legendary investor Warren Buffett advises to b...
# 1928  "Most of us have heard the dictum ""the trend ...
# 2026  Health care stocks were trending higher pre-be...
# 2027  (RTTNews) - TherapeuticsMD Inc. (TXMD) Tuesday...
# 2068  --The Necessity Retail REIT, Inc. announced to...
# 2167  (RTTNews) - MiMedx Group, Inc. (MDXG), a biome...
# 2326  (RTTNews) - The following are some of the stoc...
# 2327  (RTTNews) - The following are some of the stoc...
# 2493  Technology stocks were advancing pre-bell Tues...
# 2520  Energy stocks extended their Tuesday declines ...
# 2521  Energy stocks were trading sharply lower this ...
# 2529  Technology stocks were declining on Tuesday, w...
# 2530  Technology stocks pared a portion of their ear...
# 2567  Investors interested in Medical stocks should ...
# 2568  Investors interested in Medical stocks should ...
# 2636  Consumer stocks were mostly lower in Tuesday t...
# 2655  Bargain hunters are wise to pay careful attent...
# 2735  (RTTNews) - So-Young International Inc. (SY) a...
# 2736  Health care stocks were trending higher pre-be...
#
#                                      rld_ose_iem_tck_cd
# 9     AMAM,AMAM,EVH,GRRR,KALA,KEP,MNPR,PBR,PEGY,RMED...
# 10    AMAM,AMAM,EVH,GRRR,KALA,KEP,MNPR,PBR,PEGY,SILO...
# 179                                                 BNR
# 230                                             NVX,RIO
# 275                                                SCPH
# 311                                            AIRG,GLW
# 361                             GOTU,GOTU,AFYA,EQX,ELBM
# 447        JPM,KO,NVO,PG,H,KMB,ORCL,NOBL,MNSB,VITL,BIVI
# 469   AMAM,AMAM,EVH,GRRR,KALA,KEP,MNPR,PBR,PEGY,RMED...
# 470   AMAM,AMAM,EVH,GRRR,KALA,KEP,MNPR,PBR,PEGY,SILO...
# 471                                           DPSI,MGIC
# 647                                                CMMB
# 682                                           BLZE,FFIV
# 706                                       ASLN,ASLN,TMO
# 734                                          BELFB,PERI
# 737                                      SVRA,SVRA,THRX
# 748                                   AMN,CNC,CDNA,MDVL
# 834                                                RDHL
# 891                                      AKAM,AKAM,JUPW
# 920                                                LEDS
# 952                             CECO,TCPC,LPG,RNGR,BAND
# 1021                            RIOT,RIOT,FRME,SRG,SWKH
# 1022                                 FRME,FRME,SRG,SWKH
# 1023                                               SWKH
# 1052                             HCM,HCM,IMVT,ADTX,HSTM
# 1053                                HSTM,HSTM,ADTX,IMVT
# 1110                                               IVVD
# 1115                                               JSPR
# 1246                                HSTM,HSTM,ADTX,IMVT
# 1247                             HCM,HCM,IMVT,ADTX,HSTM
# 1293                                               EVAX
# 1475                                                GEG
# 1575                                          OZKAP,OZK
# 1688                           XLV,XLV,VHT,TXMD,SY,NRXP
# 1725                                               NVIV
# 1751         YUM,MOMO,KWEB,BILI,PDD,QFIN,COIN,HOOD,ATAT
# 1791                                               CTKB
# 1928                                               PROF
# 2026                           XLV,XLV,VHT,TXMD,SY,NRXP
# 2027                                               TXMD
# 2068                                    RTLPO,RTLPP,RTL
# 2167                                               MDXG
# 2326  AMAM,AMAM,EVH,GRRR,KALA,KEP,MNPR,PBR,PEGY,RMED...
# 2327  AMAM,AMAM,EVH,GRRR,KALA,KEP,MNPR,PBR,PEGY,SILO...
# 2493                           XLK,XLK,SOXX,OUST,CYN,IQ
# 2520                         TRGP,TRGP,BX,WFRD,WHD,EZFL
# 2521                                 WFRD,WFRD,WHD,EZFL
# 2529                                   SIDU,SIDU,TDY,IQ
# 2530                              IDCC,IDCC,SIDU,TDY,IQ
# 2567                                          DICE,NUVL
# 2568                                               NUVL
# 2636                           BIOX,BIOX,SANW,TSLA,OTLY
# 2655                                     SVRA,SVRA,THRX
# 2735                                                 SY
# 2736                           XLV,XLV,VHT,TXMD,SY,NRXP
# 개수: 55

# %% [markdown]
# ### 기초 통계 확인

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146914 entries, 0 to 146913
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   rgs_dt              146914 non-null  datetime64[ns]
#  1   tck_iem_cd          146914 non-null  object
#  2   til_ifo             146914 non-null  object
#  3   ctgy_cfc_ifo        146914 non-null  object
#  4   mdi_ifo             146914 non-null  object
#  5   news_smy_ifo        146914 non-null  object
#  6   rld_ose_iem_tck_cd  146914 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 7.8+ MB

# %%
# 누락값 및 고유값 확인
print("Missing values per column:")
print(news.isnull().sum())
print("\nUnique counts per column:")
print(news.nunique())
# Out:
# Missing values per column:
# rgs_dt                0
# tck_iem_cd            0
# til_ifo               0
# ctgy_cfc_ifo          0
# mdi_ifo               0
# news_smy_ifo          0
# rld_ose_iem_tck_cd    0
# dtype: int64
#
# Unique counts per column:
# rgs_dt                  242
# tck_iem_cd             5976
# til_ifo               83328
# ctgy_cfc_ifo            511
# mdi_ifo                  32
# news_smy_ifo          79215
# rld_ose_iem_tck_cd    40129
# dtype: int64

# %%
# 날짜 범위 및 분포 확인
print("\n등록일 최소:", news['rgs_dt'].min())
print("등록일 최대:", news['rgs_dt'].max())
# Out:
# 등록일 최소: 2023-01-02 00:00:00
# 등록일 최대: 2023-08-31 00:00:00

# %%
# 날짜별 뉴스 건수 집계
news['date'] = news['rgs_dt'].dt.date
daily_counts = news.groupby('date').size()
print("\n날짜별 뉴스 건수:")
print(daily_counts)
# Out:
# 날짜별 뉴스 건수:
# date
# 2023-01-02      13
# 2023-01-03      79
# 2023-01-04      73
# 2023-01-05      56
# 2023-01-06      62
#               ...
# 2023-08-27     257
# 2023-08-28    1848
# 2023-08-29    2062
# 2023-08-30    1910
# 2023-08-31     182
# Length: 242, dtype: int64

# %%
# 날짜별 뉴스 건수 시각화
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
daily_counts.plot(title="날짜별 뉴스 건수")
plt.xlabel("날짜")
plt.ylabel("건수")
plt.grid(True)
plt.show()

# %%
# 범주형 변수 빈도수 분석 (til_ifo, ctgy_cfc_ifo)
print("\ntil_ifo 빈도수:")
print(news['til_ifo'].value_counts())
print("\nctgy_cfc_ifo 빈도수:")
print(news['ctgy_cfc_ifo'].value_counts())
# Out:
# til_ifo 빈도수:
# til_ifo
# 5 Dividend Growth Stocks With Upside To Analyst Targets                                            86
# 5 Dividend Aristocrats Where Analysts See Capital Gains                                            58
# 3 Stocks to Avoid This Week                                                                        49
# 3 Top Dividend Stocks to Maximize Your Retirement Income                                           49
# Improve Your Retirement Income with These 3 Top-Ranked Dividend Stocks                             46
#                                                                                                    ..
# Raymond James & Associates Makes Revised Proposal for $75M Investment in Republic First Bancorp     1
# scPharmaceuticals, Inc. (SCPH) Is a Great Choice for 'Trend' Investors, Here's Why                  1
# Zhihu Appoints Henry Dachuan Sha As CFO                                                             1
# France's InVivo to buy one of the world's oldest malthouses in Belgium                              1
# Here's Why PhenixFIN (PFX) is Poised for a Turnaround After Losing -10.29% in 4 Weeks               1
# Name: count, Length: 83328, dtype: int64
#
# ctgy_cfc_ifo 빈도수:
# ctgy_cfc_ifo
# Stocks,Investing                                       39957
# Markets                                                32196
# Stocks                                                 24788
# Technology                                              8133
# US Markets                                              7986
#                                                        ...
# Artificial Intelligence,Stocks,Technology,Investing        1
# World Markets,Oil                                          1
# Data and Analytics,Commodities,Gold                        1
# Markets,Culture,US Markets                                 1
# US Markets,Stocks,Commodities                              1
# Name: count, Length: 511, dtype: int64

# %% [markdown]
# ## 추가 EDA

# %%
# CategoryGroup
# ctry_cfc_info 컬럼에서 특정 키워드를 찾아 대분류(Stocks, Markets, Options 등)로 분류
def map_category_group(x):
    if not isinstance(x, str):
        return 'Others'
    x_lower = x.lower()
    if 'stocks' in x_lower:
        return 'Stocks'
    elif 'markets' in x_lower:
        return 'Markets'
    elif 'options' in x_lower:
        return 'Options'
    elif 'futures' in x_lower:
        return 'Futures'
    else:
        return 'Others'

news['CategoryGroup'] = news['ctgy_cfc_ifo'].apply(map_category_group)

# HasBuyWord / HasSellWord
# 제목(til_ifo)에 'buy', 'sell', 'short' 키워드가 포함되어 있는지 여부를 0/1로 표시
news['HasBuyWord'] = news['til_ifo'].str.contains(r'\bbuy\b', case=False, na=False).astype(int)
news['HasSellWord'] = news['til_ifo'].str.contains(r'\bsell\b', case=False, na=False).astype(int)
news['HasShortWord'] = news['til_ifo'].str.contains(r'\bshort\b', case=False, na=False).astype(int)

# 결과 확인
news.head()
# Out:
#       rgs_dt tck_iem_cd                                            til_ifo  \
# 0 2023-01-02        NGS  Hoak & Co. Urges NGS Board to Halt CEO Search ...
# 1 2023-01-02        PFX  Here's Why PhenixFIN (PFX) is Poised for a Tur...
# 2 2023-01-02        TYG     My Advice? Sell These 2 Dividend Funds in 2023
# 3 2023-01-02       NVIV  France's InVivo to buy one of the world's olde...
# 4 2023-01-02        FEN     My Advice? Sell These 2 Dividend Funds in 2023
#
#                      ctgy_cfc_ifo     mdi_ifo  \
# 0                       Investing      Fintel
# 1                Stocks,Investing       Zacks
# 2                  Markets,Stocks  BNK Invest
# 3  Commodities,BioTech,US Markets     Reuters
# 4                  Markets,Stocks  BNK Invest
#
#                                         news_smy_ifo rld_ose_iem_tck_cd  \
# 0  Fintel reports that Hoak Public Equities, LP, ...                NGS
# 1  PhenixFIN (PFX) has been beaten down lately wi...                PFX
# 2  There's a disconnect setting up in the energy ...        TYG,TYG,FEN
# 3  Malteries Soufflet, a branch of French agribus...               NVIV
# 4  There's a disconnect setting up in the energy ...        TYG,TYG,FEN
#
#          date CategoryGroup  HasBuyWord  HasSellWord  HasShortWord
# 0  2023-01-02        Others           0            0             0
# 1  2023-01-02        Stocks           0            0             0
# 2  2023-01-02        Stocks           0            1             0
# 3  2023-01-02       Markets           1            0             0
# 4  2023-01-02        Stocks           0            1             0

# %%
news.drop(columns=['rld_ose_iem_tck_cd', 'rgs_dt'], inplace=True, errors='ignore')
news.head()
# Out:
#   tck_iem_cd                                            til_ifo  \
# 0        NGS  Hoak & Co. Urges NGS Board to Halt CEO Search ...
# 1        PFX  Here's Why PhenixFIN (PFX) is Poised for a Tur...
# 2        TYG     My Advice? Sell These 2 Dividend Funds in 2023
# 3       NVIV  France's InVivo to buy one of the world's olde...
# 4        FEN     My Advice? Sell These 2 Dividend Funds in 2023
#
#                      ctgy_cfc_ifo     mdi_ifo  \
# 0                       Investing      Fintel
# 1                Stocks,Investing       Zacks
# 2                  Markets,Stocks  BNK Invest
# 3  Commodities,BioTech,US Markets     Reuters
# 4                  Markets,Stocks  BNK Invest
#
#                                         news_smy_ifo        date  \
# 0  Fintel reports that Hoak Public Equities, LP, ...  2023-01-02
# 1  PhenixFIN (PFX) has been beaten down lately wi...  2023-01-02
# 2  There's a disconnect setting up in the energy ...  2023-01-02
# 3  Malteries Soufflet, a branch of French agribus...  2023-01-02
# 4  There's a disconnect setting up in the energy ...  2023-01-02
#
#   CategoryGroup  HasBuyWord  HasSellWord  HasShortWord
# 0        Others           0            0             0
# 1        Stocks           0            0             0
# 2        Stocks           0            1             0
# 3       Markets           1            0             0
# 4        Stocks           0            1             0

# %% [markdown]
# ## W2
# ### Task1. 시각화

# %%
# !pip install wordcloud
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import re
from collections import Counter
import seaborn as sns
import pandas as pd
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
# 1) 텍스트 전처리
text_data = " ".join(news['til_ifo'].astype(str).tolist())
text_data = re.sub(r'[^a-zA-Z ]', '', text_data.lower())

# 2) WordCloud에 사용할 stopwords 정의
my_stopwords = set(STOPWORDS)
# 내장된 영어 불용어 외에 추가로 제거할 단어
my_stopwords.update(["to", "for", "the", "and", "of", "in", "on", "q", "stocks", "stock", "earnings"])

# 3) 워드클라우드 생성 시 stopwords 인자로 전달
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    stopwords=my_stopwords  # 불용어 세트
).generate(text_data)

# 4) 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud (with Stopwords Removed)')
plt.show()

# %%
# 3) 전체 단어 리스트로 분할
words = text_data.split()

# 4) 불용어 제거
filtered_words = [w for w in words if w not in my_stopwords]

# 5) 단어 빈도 계산
word_counts = Counter(filtered_words)
most_common_20 = word_counts.most_common(20)

# 6) DataFrame 변환 및 시각화
df_common_20 = pd.DataFrame(most_common_20, columns=['word', 'count'])

plt.figure(figsize=(8, 5))
sns.barplot(data=df_common_20, x='count', y='word', palette='Blues_r')
plt.title('Top 20 Most Frequent Words (Stopwords Removed)')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.show()

# %%
# 날짜 컬럼을 datetime으로 변환
news['date'] = pd.to_datetime(news['date'])

# 요일 추출 (월=0, 화=1, ... 일=6)
news['weekday'] = news['date'].dt.weekday

# 요일별 기사 수
weekday_count = news.groupby('weekday').size().reset_index(name='count')

# 요일 이름 매핑
weekday_map = {
    0: 'Mon',
    1: 'Tue',
    2: 'Wed',
    3: 'Thu',
    4: 'Fri',
    5: 'Sat',
    6: 'Sun'
}
weekday_count['weekday_name'] = weekday_count['weekday'].map(weekday_map)

# 시각화
plt.figure(figsize=(8, 5))
sns.barplot(data=weekday_count, x='weekday_name', y='count', palette='Set2')
plt.title('News Articles by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Article Count')
plt.show()

# %%
# 카테고리별 기사 수 계산
category_counts = news['CategoryGroup'].value_counts()

# 예: 상위 20개 카테고리만 추출
topN = 20
top_categories = category_counts.head(topN).index

# 상위 20개 카테고리에 해당하는 데이터만 필터링
news_topN = news[news['CategoryGroup'].isin(top_categories)]

plt.figure(figsize=(12, 6))
sns.countplot(data=news_topN, x='CategoryGroup', order=top_categories)
plt.title(f'News Articles by Top {topN} Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # 레이블 45도 회전, 오른쪽 정렬
plt.tight_layout()
plt.show()

# %%
# !pip install textblob
from textblob import TextBlob

# 간단한 감성 분석 함수 정의 (영어 텍스트 기준)
def get_sentiment_score(text):
    return TextBlob(text).sentiment.polarity  # -1(부정) ~ +1(긍정)

# 'til_ifo' 컬럼에 대해 감성 점수 계산
news['sentiment_score'] = news['til_ifo'].astype(str).apply(get_sentiment_score)
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.11/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
# 제목 길이 계산
news['title_length'] = news['til_ifo'].astype(str).apply(len)

# 산점도 시각화
plt.figure(figsize=(8, 5))
sns.scatterplot(data=news, x='title_length', y='sentiment_score', alpha=0.7)
plt.title('Sentiment Score vs. Title Length')
plt.xlabel('Title Length (Characters)')
plt.ylabel('Sentiment Score')
plt.show()

# %% [markdown]
# ### Task 2
#
# # EDA 분석 노트
#
# ## 1. 데이터 컬럼별 특징 요약
#
# ### (1) `til_ifo` (뉴스 제목)
# - **주요 단어 빈도**
#   - 상위 단어로 `buy`, `recommendation`, `estimates`, `maintains`, `report` 등이 관찰됨
#   - 투자 의견(`buy`, `recommendation`) 및 애널리스트 리포트(`report`, `estimates`) 관련 단어가 많아, 뉴스가 **주식·투자** 분야에 집중되어 있음을 시사
# - **인사이트**
#   - 제목에 “buy”나 “recommendation” 등이 들어간 기사는 긍정적(매수) 뉘앙스를 줄 가능성이 큼
#   - “maintains”, “report”와 같은 키워드도 실적 발표나 분석 보고서 관련 뉴스를 가리킬 수 있음
#
# ### (2) `rgs_dt` (등록일)
# - **요일별 기사 수**
#   - 월~목: 기사량이 많음
#   - 금요일: 상대적으로 감소
#   - 주말(토·일): 기사량이 크게 줄어듦
# - **의미**
#   - 금융 시장이 평일에 개장하는 특성 반영
#   - 주말에는 시장 휴장으로 인해 기사 발행이 적음
# - **인사이트**
#   - 날짜를 `Month`, `Year`, `Quarter` 등으로 변환하여 시계열 트렌드를 살펴볼 수도 있음
#
# ### (3) `ctgy_clc` (카테고리)
# - **상위 카테고리**
#   - Stocks Analysis, Markets, Stock News, Market Stock Options, Market Stock ETFs 등
#   - 주식/시장/ETF/옵션 관련이 대부분
# - **인사이트**
#   - 카테고리 종류가 많다면 **그룹화**를 통해 큰 범주별(주식, ETF, 옵션, 배당, 실적 등)로 나누어 볼 수 있음
#   - 특정 카테고리(예: Dividends, Earnings 등)만 따로 분석해, 배당주 관련 뉴스 혹은 실적 발표 관련 뉴스를 집중적으로 탐색 가능
#
# ---
#
# ## 2. 추가 변수 아이디어
#
#
# 1. **`sentiment_label`**
#    - 감성 점수를 임계값에 따라 `Positive`, `Neutral`, `Negative`로 분류
#    - 시각화나 통계 분석 시 편리
#
# 2. **`CategoryGroup`**
#    - `ctgy_clc`를 더 큰 범주로 묶은 새 컬럼
#    - 예: `Stocks`, `Markets`, `Options`, `Earnings`, `Dividends` 등
#    - 카테고리가 지나치게 많을 경우, EDA가 복잡해지므로 그룹화 권장
#
# 3. **`HasBuyWord` / `HasSellWord`**
#    - 제목이나 본문에 `buy`, `sell`, `short` 등 특정 키워드가 등장하는지 0/1로 표시
#    - 매수/매도 의견 관련 기사를 구분하는 데 활용 가능
#
# 4. **시계열 변수**
#    - `Month`, `Quarter`, `Year` 등으로 구분해 **월별·분기별 추이** 분석
#
# ---
#
# ## 3. 종합 의견
#
# - 본 데이터셋은 주식·시장·ETF·옵션 등 **투자 관련 뉴스**가 주를 이룸.
# - 평일에 기사량이 집중되고, 주말에는 적은 편.
# - “buy”나 “recommendation” 같은 **투자 의견** 키워드가 많음.
# - **추가 파생 변수**(IsWeekend, CategoryGroup, sentiment_label 등)를 생성하고,
#   - 감성 점수와 날짜·카테고리·특정 키워드 포함 여부 등을 **교차 분석**하면 더 심도 있는 인사이트를 얻을 수 있음.
#
# 위 내용들을 기반으로, **주가 변동**이나 **거래량** 같은 외부 지표와 연계하여 분석을 확장해야 할 듯함
# 예를 들어, "긍정 감성 기사가 많은 날, 실제 주가가 상승했는가?” 등을 확인함으로써 **뉴스 감성**과 **시장 반응** 간의 상관관계를 탐색
