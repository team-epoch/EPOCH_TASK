# %% [markdown]
# # Brazilian E-Commerce Public Dataset by Olist

# %%
import numpy as np
import pandas as pd
from unidecode import unidecode

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("ticks")
# %matplotlib inline

import os

from datetime import datetime
from datetime import timedelta
# import missingno as msno

import warnings
warnings.filterwarnings(action='ignore')

pd.set_option("display.max_columns", None)

plt.rc('font', family='Noto Sans')
plt.rcParams['axes.unicode_minus'] = False

# %%
# # 데이터 불러오기
# file_path = "../data/total_merged.csv"
# df = pd.read_csv(file_path, index_col = 0)
# df.head(3)

# %%
orders = pd.read_csv('../data/olist_orders_dataset.csv')
order_items = pd.read_csv('../data/olist_order_items_dataset.csv')
customers = pd.read_csv('../data/olist_customers_dataset.csv')
order_payments = pd.read_csv('../data/olist_order_payments_dataset.csv')
products = pd.read_csv('../data/olist_products_dataset.csv')

# %%
print("orders columns:", orders.columns.tolist())
print("order_items_products columns:", products.columns.tolist())
# Out:
# orders columns: ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
# order_items_products columns: ['product_id', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']

# %%
# 2. 각 데이터셋의 컬럼 확인 (필요에 따라 데이터 전처리 진행)
print("Orders Columns:", orders.columns.tolist())
print("Order Items Columns:", order_items.columns.tolist())
print("Customers Columns:", customers.columns.tolist())
print("Order Payments Columns:", order_payments.columns.tolist())
print("Products Columns:", products.columns.tolist())

# 3. Order Items와 Products 병합
# - Merge Key: product_id
# - order_items 데이터셋에 제품 정보를 추가하기 위해 products 데이터셋과 병합합니다.
order_items_products = order_items.merge(products, on='product_id', how='left')
print("Order Items & Products Merge:")
print(order_items_products.head())

# 4. 전체 데이터셋 통합
# - Orders, Order Items+Products, Order Payments, Customers 순서로 병합합니다.
df = orders.merge(order_items_products, on='order_id', how='inner') \
                   .merge(order_payments, on='order_id', how='inner') \
                   .merge(customers, on='customer_id', how='inner', suffixes=('_order', '_customer'))

# 5. 최종 통합 데이터 확인
print("Fully Merged DataFrame:")
df.head()
# Out:
# Orders Columns: ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
# Order Items Columns: ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
# Customers Columns: ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
# Order Payments Columns: ['order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']
# Products Columns: ['product_id', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
# Order Items & Products Merge:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# 2  2018-01-18 14:48:30  199.00          17.87      moveis_decoracao
# 3  2018-08-15 10:10:18   12.99          12.79            perfumaria
# 4  2017-02-13 13:57:51  199.90          18.14    ferramentas_jardim
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 58.0                       598.0                 4.0
# 1                 56.0                       239.0                 2.0
# 2                 59.0                       695.0                 2.0
# 3                 42.0                       480.0                 1.0
# 4                 59.0                       409.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             650.0               28.0                9.0              14.0
# 1           30000.0               50.0               30.0              40.0
# 2            3050.0               33.0               13.0              33.0
# 3             200.0               16.0               10.0              15.0
# 4            3750.0               35.0               40.0              30.0
# Fully Merged DataFrame:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date  order_item_id  \
# 0           2017-10-18 00:00:00              1
# 1           2017-10-18 00:00:00              1
# 2           2017-10-18 00:00:00              1
# 3           2018-08-13 00:00:00              1
# 4           2018-09-04 00:00:00              1
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 2  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 3  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 4  aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
#
#    shipping_limit_date   price  freight_value  product_category_name  \
# 0  2017-10-06 11:07:15   29.99           8.72  utilidades_domesticas
# 1  2017-10-06 11:07:15   29.99           8.72  utilidades_domesticas
# 2  2017-10-06 11:07:15   29.99           8.72  utilidades_domesticas
# 3  2018-07-30 03:24:27  118.70          22.76             perfumaria
# 4  2018-08-13 08:55:23  159.90          19.22             automotivo
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       268.0                 4.0
# 1                 40.0                       268.0                 4.0
# 2                 40.0                       268.0                 4.0
# 3                 29.0                       178.0                 1.0
# 4                 46.0                       232.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             500.0               19.0                8.0              13.0
# 1             500.0               19.0                8.0              13.0
# 2             500.0               19.0                8.0              13.0
# 3             400.0               19.0               13.0              19.0
# 4             420.0               24.0               19.0              21.0
#
#    payment_sequential payment_type  payment_installments  payment_value  \
# 0                   1  credit_card                     1          18.12
# 1                   3      voucher                     1           2.00
# 2                   2      voucher                     1          18.59
# 3                   1       boleto                     1         141.46
# 4                   1  credit_card                     3         179.12
#
#                  customer_unique_id  customer_zip_code_prefix customer_city  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 1  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 2  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 3  af07308b275d755c9edb36a90c618231                     47813     barreiras
# 4  3a653a41f6f9fc3d2a113cf8398680e8                     75265    vianopolis
#
#   customer_state
# 0             SP
# 1             SP
# 2             SP
# 3             BA
# 4             GO

# %%
df.shape
# Out:
# (117601, 30)

# %% [markdown]
# ## TASK 1: 데이터 전처리

# %% [markdown]
# ### 1-1. 결측치 비율 시각화 및 결측치 처리
# - 결측치 비율 `10% 미만` : 제거 또는 대체
# - 결측치 비율 `10% 이상 20% 미만` : 모델 기반 처리
# - 결측치 비율 `20% 이상` : 모델 기반 처리

# %%
# 결측치 비율 구함
null_total = df.isnull().sum()
null_count = df.isnull().count()
null_pct = round((null_total/null_count)*100, 1)

# 결측치 개수, 퍼센트 데이터프레임으로 생성
missing = pd.concat([null_total, null_pct], axis=1, keys=["Total", "Percent"])
missing
# Out:
#                                Total  Percent
# order_id                           0      0.0
# customer_id                        0      0.0
# order_status                       0      0.0
# order_purchase_timestamp           0      0.0
# order_approved_at                 15      0.0
# order_delivered_carrier_date    1245      1.1
# order_delivered_customer_date   2567      2.2
# order_estimated_delivery_date      0      0.0
# order_item_id                      0      0.0
# product_id                         0      0.0
# seller_id                          0      0.0
# shipping_limit_date                0      0.0
# price                              0      0.0
# freight_value                      0      0.0
# product_category_name           1698      1.4
# product_name_lenght             1698      1.4
# product_description_lenght      1698      1.4
# product_photos_qty              1698      1.4
# product_weight_g                  20      0.0
# product_length_cm                 20      0.0
# product_height_cm                 20      0.0
# product_width_cm                  20      0.0
# payment_sequential                 0      0.0
# payment_type                       0      0.0
# payment_installments               0      0.0
# payment_value                      0      0.0
# customer_unique_id                 0      0.0
# customer_zip_code_prefix           0      0.0
# customer_city                      0      0.0
# customer_state                     0      0.0

# %%
# 결측치 비율 시각화
plt.figure(figsize=(10, 5))
sns_pct = sns.barplot(x="index", y="Percent", data=missing[missing["Total"]!=0].reset_index())
sns_pct.set_xticklabels(sns_pct.get_xticklabels(), rotation=45)

# bar 그래프 상단에 비율 (%) 표기
for bar in sns_pct.patches:
    height = bar.get_height()                   # .get_height() : y좌표

    plt.text(bar.get_x() + bar.get_width()/2,   # 퍼센트 글자 위치
             height+0.01,                        # 퍼센트 글자 높이
             "%.1f" % height,                   # 퍼센트 소수점 지정
             ha="center")                       # 가운데 정렬

# 시각화 제목 이름, 폰트 크기 지정
sns_pct.set_title("Total Missing Value (%)", fontsize=15)
plt.show()

# %% [markdown]
# 결측치가 존재하는 컬럼들의 결측치 비율이 매우 낮다 (약 1 ~ 2%) → 제거하기로 결정

# %%
# 결측치 처리 전과 처리 후 비교
print("결측치 drop 전 데이터프레임 row 수 :", df.shape[0])
print("결측치 drop 후 데이터프레임 row 수 :", df.dropna().shape[0])
print("결측치 drop 비율", round((df.shape[0]-df.dropna().shape[0])/df.shape[0], 2), "%")

# 결측치 제거
df_mod = df.dropna()
# Out:
# 결측치 drop 전 데이터프레임 row 수 : 117601
# 결측치 drop 후 데이터프레임 row 수 : 113390
# 결측치 drop 비율 0.04 %

# %% [markdown]
# ### 1-2. 주요 시각화

# %%
# 결제 날짜에서 연도만 빼온다
df_mod["purchased_year"] = pd.to_datetime(df_mod["order_purchase_timestamp"]).dt.year
df_mod["purchased_month"] = pd.to_datetime(df_mod["order_purchase_timestamp"]).dt.month

df_mod.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
#
#   order_estimated_delivery_date  order_item_id  \
# 0           2017-10-18 00:00:00              1
# 1           2017-10-18 00:00:00              1
# 2           2017-10-18 00:00:00              1
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 2  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
#
#    shipping_limit_date  price  freight_value  product_category_name  \
# 0  2017-10-06 11:07:15  29.99           8.72  utilidades_domesticas
# 1  2017-10-06 11:07:15  29.99           8.72  utilidades_domesticas
# 2  2017-10-06 11:07:15  29.99           8.72  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       268.0                 4.0
# 1                 40.0                       268.0                 4.0
# 2                 40.0                       268.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             500.0               19.0                8.0              13.0
# 1             500.0               19.0                8.0              13.0
# 2             500.0               19.0                8.0              13.0
#
#    payment_sequential payment_type  payment_installments  payment_value  \
# 0                   1  credit_card                     1          18.12
# 1                   3      voucher                     1           2.00
# 2                   2      voucher                     1          18.59
#
#                  customer_unique_id  customer_zip_code_prefix customer_city  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 1  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 2  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
#
#   customer_state  purchased_year  purchased_month
# 0             SP            2017               10
# 1             SP            2017               10
# 2             SP            2017               10

# %%
city_counts = df_mod.groupby(["customer_city"]).count()
city_top10 = city_counts.sort_values(by="order_id", ascending=False).head(10)
city_top10
# Out:
#                        order_id  customer_id  order_status  \
# customer_city
# sao paulo                 17868        17868         17868
# rio de janeiro             7822         7822          7822
# belo horizonte             3134         3134          3134
# brasilia                   2374         2374          2374
# curitiba                   1768         1768          1768
# campinas                   1686         1686          1686
# porto alegre               1589         1589          1589
# salvador                   1435         1435          1435
# guarulhos                  1348         1348          1348
# sao bernardo do campo      1075         1075          1075
#
#                        order_purchase_timestamp  order_approved_at  \
# customer_city
# sao paulo                                 17868              17868
# rio de janeiro                             7822               7822
# belo horizonte                             3134               3134
# brasilia                                   2374               2374
# curitiba                                   1768               1768
# campinas                                   1686               1686
# porto alegre                               1589               1589
# salvador                                   1435               1435
# guarulhos                                  1348               1348
# sao bernardo do campo                      1075               1075
#
#                        order_delivered_carrier_date  \
# customer_city
# sao paulo                                     17868
# rio de janeiro                                 7822
# belo horizonte                                 3134
# brasilia                                       2374
# curitiba                                       1768
# campinas                                       1686
# porto alegre                                   1589
# salvador                                       1435
# guarulhos                                      1348
# sao bernardo do campo                          1075
#
#                        order_delivered_customer_date  \
# customer_city
# sao paulo                                      17868
# rio de janeiro                                  7822
# belo horizonte                                  3134
# brasilia                                        2374
# curitiba                                        1768
# campinas                                        1686
# porto alegre                                    1589
# salvador                                        1435
# guarulhos                                       1348
# sao bernardo do campo                           1075
#
#                        order_estimated_delivery_date  order_item_id  \
# customer_city
# sao paulo                                      17868          17868
# rio de janeiro                                  7822           7822
# belo horizonte                                  3134           3134
# brasilia                                        2374           2374
# curitiba                                        1768           1768
# campinas                                        1686           1686
# porto alegre                                    1589           1589
# salvador                                        1435           1435
# guarulhos                                       1348           1348
# sao bernardo do campo                           1075           1075
#
#                        product_id  seller_id  shipping_limit_date  price  \
# customer_city
# sao paulo                   17868      17868                17868  17868
# rio de janeiro               7822       7822                 7822   7822
# belo horizonte               3134       3134                 3134   3134
# brasilia                     2374       2374                 2374   2374
# curitiba                     1768       1768                 1768   1768
# campinas                     1686       1686                 1686   1686
# porto alegre                 1589       1589                 1589   1589
# salvador                     1435       1435                 1435   1435
# guarulhos                    1348       1348                 1348   1348
# sao bernardo do campo        1075       1075                 1075   1075
#
#                        freight_value  product_category_name  \
# customer_city
# sao paulo                      17868                  17868
# rio de janeiro                  7822                   7822
# belo horizonte                  3134                   3134
# brasilia                        2374                   2374
# curitiba                        1768                   1768
# campinas                        1686                   1686
# porto alegre                    1589                   1589
# salvador                        1435                   1435
# guarulhos                       1348                   1348
# sao bernardo do campo           1075                   1075
#
#                        product_name_lenght  product_description_lenght  \
# customer_city
# sao paulo                            17868                       17868
# rio de janeiro                        7822                        7822
# belo horizonte                        3134                        3134
# brasilia                              2374                        2374
# curitiba                              1768                        1768
# campinas                              1686                        1686
# porto alegre                          1589                        1589
# salvador                              1435                        1435
# guarulhos                             1348                        1348
# sao bernardo do campo                 1075                        1075
#
#                        product_photos_qty  product_weight_g  \
# customer_city
# sao paulo                           17868             17868
# rio de janeiro                       7822              7822
# belo horizonte                       3134              3134
# brasilia                             2374              2374
# curitiba                             1768              1768
# campinas                             1686              1686
# porto alegre                         1589              1589
# salvador                             1435              1435
# guarulhos                            1348              1348
# sao bernardo do campo                1075              1075
#
#                        product_length_cm  product_height_cm  product_width_cm  \
# customer_city
# sao paulo                          17868              17868             17868
# rio de janeiro                      7822               7822              7822
# belo horizonte                      3134               3134              3134
# brasilia                            2374               2374              2374
# curitiba                            1768               1768              1768
# campinas                            1686               1686              1686
# porto alegre                        1589               1589              1589
# salvador                            1435               1435              1435
# guarulhos                           1348               1348              1348
# sao bernardo do campo               1075               1075              1075
#
#                        payment_sequential  payment_type  payment_installments  \
# customer_city
# sao paulo                           17868         17868                 17868
# rio de janeiro                       7822          7822                  7822
# belo horizonte                       3134          3134                  3134
# brasilia                             2374          2374                  2374
# curitiba                             1768          1768                  1768
# campinas                             1686          1686                  1686
# porto alegre                         1589          1589                  1589
# salvador                             1435          1435                  1435
# guarulhos                            1348          1348                  1348
# sao bernardo do campo                1075          1075                  1075
#
#                        payment_value  customer_unique_id  \
# customer_city
# sao paulo                      17868               17868
# rio de janeiro                  7822                7822
# belo horizonte                  3134                3134
# brasilia                        2374                2374
# curitiba                        1768                1768
# campinas                        1686                1686
# porto alegre                    1589                1589
# salvador                        1435                1435
# guarulhos                       1348                1348
# sao bernardo do campo           1075                1075
#
#                        customer_zip_code_prefix  customer_state  \
# customer_city
# sao paulo                                 17868           17868
# rio de janeiro                             7822            7822
# belo horizonte                             3134            3134
# brasilia                                   2374            2374
# curitiba                                   1768            1768
# campinas                                   1686            1686
# porto alegre                               1589            1589
# salvador                                   1435            1435
# guarulhos                                  1348            1348
# sao bernardo do campo                      1075            1075
#
#                        purchased_year  purchased_month
# customer_city
# sao paulo                       17868            17868
# rio de janeiro                   7822             7822
# belo horizonte                   3134             3134
# brasilia                         2374             2374
# curitiba                         1768             1768
# campinas                         1686             1686
# porto alegre                     1589             1589
# salvador                         1435             1435
# guarulhos                        1348             1348
# sao bernardo do campo            1075             1075

# %%
payment_counts = df_mod.groupby("payment_type").count()
payment_counts = payment_counts.sort_values(by="order_id", ascending=False)
payment_counts
# Out:
#               order_id  customer_id  order_status  order_purchase_timestamp  \
# payment_type
# credit_card      83706        83706         83706                     83706
# boleto           22047        22047         22047                     22047
# voucher           6012         6012          6012                      6012
# debit_card        1625         1625          1625                      1625
#
#               order_approved_at  order_delivered_carrier_date  \
# payment_type
# credit_card               83706                         83706
# boleto                    22047                         22047
# voucher                    6012                          6012
# debit_card                 1625                          1625
#
#               order_delivered_customer_date  order_estimated_delivery_date  \
# payment_type
# credit_card                           83706                          83706
# boleto                                22047                          22047
# voucher                                6012                           6012
# debit_card                             1625                           1625
#
#               order_item_id  product_id  seller_id  shipping_limit_date  \
# payment_type
# credit_card           83706       83706      83706                83706
# boleto                22047       22047      22047                22047
# voucher                6012        6012       6012                 6012
# debit_card             1625        1625       1625                 1625
#
#               price  freight_value  product_category_name  \
# payment_type
# credit_card   83706          83706                  83706
# boleto        22047          22047                  22047
# voucher        6012           6012                   6012
# debit_card     1625           1625                   1625
#
#               product_name_lenght  product_description_lenght  \
# payment_type
# credit_card                 83706                       83706
# boleto                      22047                       22047
# voucher                      6012                        6012
# debit_card                   1625                        1625
#
#               product_photos_qty  product_weight_g  product_length_cm  \
# payment_type
# credit_card                83706             83706              83706
# boleto                     22047             22047              22047
# voucher                     6012              6012               6012
# debit_card                  1625              1625               1625
#
#               product_height_cm  product_width_cm  payment_sequential  \
# payment_type
# credit_card               83706             83706               83706
# boleto                    22047             22047               22047
# voucher                    6012              6012                6012
# debit_card                 1625              1625                1625
#
#               payment_installments  payment_value  customer_unique_id  \
# payment_type
# credit_card                  83706          83706               83706
# boleto                       22047          22047               22047
# voucher                       6012           6012                6012
# debit_card                    1625           1625                1625
#
#               customer_zip_code_prefix  customer_city  customer_state  \
# payment_type
# credit_card                      83706          83706           83706
# boleto                           22047          22047           22047
# voucher                           6012           6012            6012
# debit_card                        1625           1625            1625
#
#               purchased_year  purchased_month
# payment_type
# credit_card            83706            83706
# boleto                 22047            22047
# voucher                 6012             6012
# debit_card              1625             1625

# %%
category_counts = df_mod.groupby("product_category_name").count()
category_counts = category_counts.sort_values(by="order_id", ascending=False).head(5)
category_counts
# Out:
#                         order_id  customer_id  order_status  \
# product_category_name
# cama_mesa_banho            11649        11649         11649
# beleza_saude                9761         9761          9761
# esporte_lazer               8731         8731          8731
# moveis_decoracao            8553         8553          8553
# informatica_acessorios      7897         7897          7897
#
#                         order_purchase_timestamp  order_approved_at  \
# product_category_name
# cama_mesa_banho                            11649              11649
# beleza_saude                                9761               9761
# esporte_lazer                               8731               8731
# moveis_decoracao                            8553               8553
# informatica_acessorios                      7897               7897
#
#                         order_delivered_carrier_date  \
# product_category_name
# cama_mesa_banho                                11649
# beleza_saude                                    9761
# esporte_lazer                                   8731
# moveis_decoracao                                8553
# informatica_acessorios                          7897
#
#                         order_delivered_customer_date  \
# product_category_name
# cama_mesa_banho                                 11649
# beleza_saude                                     9761
# esporte_lazer                                    8731
# moveis_decoracao                                 8553
# informatica_acessorios                           7897
#
#                         order_estimated_delivery_date  order_item_id  \
# product_category_name
# cama_mesa_banho                                 11649          11649
# beleza_saude                                     9761           9761
# esporte_lazer                                    8731           8731
# moveis_decoracao                                 8553           8553
# informatica_acessorios                           7897           7897
#
#                         product_id  seller_id  shipping_limit_date  price  \
# product_category_name
# cama_mesa_banho              11649      11649                11649  11649
# beleza_saude                  9761       9761                 9761   9761
# esporte_lazer                 8731       8731                 8731   8731
# moveis_decoracao              8553       8553                 8553   8553
# informatica_acessorios        7897       7897                 7897   7897
#
#                         freight_value  product_name_lenght  \
# product_category_name
# cama_mesa_banho                 11649                11649
# beleza_saude                     9761                 9761
# esporte_lazer                    8731                 8731
# moveis_decoracao                 8553                 8553
# informatica_acessorios           7897                 7897
#
#                         product_description_lenght  product_photos_qty  \
# product_category_name
# cama_mesa_banho                              11649               11649
# beleza_saude                                  9761                9761
# esporte_lazer                                 8731                8731
# moveis_decoracao                              8553                8553
# informatica_acessorios                        7897                7897
#
#                         product_weight_g  product_length_cm  \
# product_category_name
# cama_mesa_banho                    11649              11649
# beleza_saude                        9761               9761
# esporte_lazer                       8731               8731
# moveis_decoracao                    8553               8553
# informatica_acessorios              7897               7897
#
#                         product_height_cm  product_width_cm  \
# product_category_name
# cama_mesa_banho                     11649             11649
# beleza_saude                         9761              9761
# esporte_lazer                        8731              8731
# moveis_decoracao                     8553              8553
# informatica_acessorios               7897              7897
#
#                         payment_sequential  payment_type  \
# product_category_name
# cama_mesa_banho                      11649         11649
# beleza_saude                          9761          9761
# esporte_lazer                         8731          8731
# moveis_decoracao                      8553          8553
# informatica_acessorios                7897          7897
#
#                         payment_installments  payment_value  \
# product_category_name
# cama_mesa_banho                        11649          11649
# beleza_saude                            9761           9761
# esporte_lazer                           8731           8731
# moveis_decoracao                        8553           8553
# informatica_acessorios                  7897           7897
#
#                         customer_unique_id  customer_zip_code_prefix  \
# product_category_name
# cama_mesa_banho                      11649                     11649
# beleza_saude                          9761                      9761
# esporte_lazer                         8731                      8731
# moveis_decoracao                      8553                      8553
# informatica_acessorios                7897                      7897
#
#                         customer_city  customer_state  purchased_year  \
# product_category_name
# cama_mesa_banho                 11649           11649           11649
# beleza_saude                     9761            9761            9761
# esporte_lazer                    8731            8731            8731
# moveis_decoracao                 8553            8553            8553
# informatica_acessorios           7897            7897            7897
#
#                         purchased_month
# product_category_name
# cama_mesa_banho                   11649
# beleza_saude                       9761
# esporte_lazer                      8731
# moveis_decoracao                   8553
# informatica_acessorios             7897

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
fig.suptitle('Charts for E-Commerce Data', fontsize=16, fontweight='bold')

# 첫 번째 plot
sns.barplot(data=city_top10, x="customer_city", y="customer_id", ax=axes[0, 0], hue="customer_city")
axes[0, 0].set_ylabel('Count')
axes[0, 0].set_title('Customer City')
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45)

# 두 번째 plot
sns.barplot(data=payment_counts, x="order_id", y="payment_type", ax=axes[0, 1], hue="payment_type")
axes[0, 0].set_xlabel('Count')
axes[0, 1].set_title('Payment Count')

# 세 번째 plot
wedges, texts, autotexts = axes[1, 0].pie(category_counts['order_id'], 
               labels=category_counts.index, 
               autopct="%1.1f%%", 
               startangle=90)
axes[1, 0].set_title('Purchased Category Top 5')

# 네 번째 plot
sns.lineplot(data=df_mod, x="purchased_year", y="price", hue="payment_type", marker='o', ax=axes[1, 1])
axes[1, 1].set_xticks([2016, 2017, 2018])
axes[1, 1].set_xticklabels(['2016', '2017', '2018'])
axes[1, 1].set_title('Average Price per Year')

fig.tight_layout()
plt.show()

# %% [markdown]
# ### 1-3. 상관 관계 확인

# %%
num_cols = df_mod.select_dtypes(include="number").columns.tolist()
df_mod_corr = round(df_mod[num_cols].corr(), 2)

df_mod_corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_5e1d1_row0_col0, #T_5e1d1_row1_col1, #T_5e1d1_row2_col2, #T_5e1d1_row3_col3, #T_5e1d1_row4_col4, #T_5e1d1_row5_col5, #T_5e1d1_row6_col6, #T_5e1d1_row7_col7, #T_5e1d1_row8_col8, #T_5e1d1_row9_col9, #T_5e1d1_row10_col10, #T_5e1d1_row11_col11, #T_5e1d1_row12_col12, #T_5e1d1_row13_col13, #T_5e1d1_row14_col14, #T_5e1d1_row15_col15 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5e1d1_row0_col1, #T_5e1d1_row0_col2, #T_5e1d1_row0_col5, #T_5e1d1_row1_col0, #T_5e1d1_row3_col8, #T_5e1d1_row4_col9, #T_5e1d1_row5_col8, #T_5e1d1_row8_col3, #T_5e1d1_row9_col4, #T_5e1d1_row10_col11, #T_5e1d1_row10_col12, #T_5e1d1_row10_col13, #T_5e1d1_row11_col10, #T_5e1d1_row14_col6, #T_5e1d1_row14_col7, #T_5e1d1_row14_col8, #T_5e1d1_row14_col13, #T_5e1d1_row14_col15, #T_5e1d1_row15_col14 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5e1d1_row0_col3, #T_5e1d1_row5_col0, #T_5e1d1_row14_col9, #T_5e1d1_row15_col6 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_5e1d1_row0_col4, #T_5e1d1_row0_col7, #T_5e1d1_row0_col8, #T_5e1d1_row0_col9, #T_5e1d1_row2_col3, #T_5e1d1_row3_col2, #T_5e1d1_row6_col0, #T_5e1d1_row9_col5, #T_5e1d1_row10_col0, #T_5e1d1_row10_col1, #T_5e1d1_row10_col4, #T_5e1d1_row12_col5, #T_5e1d1_row13_col0, #T_5e1d1_row13_col9, #T_5e1d1_row13_col10, #T_5e1d1_row14_col0, #T_5e1d1_row14_col1, #T_5e1d1_row15_col0, #T_5e1d1_row15_col1, #T_5e1d1_row15_col4, #T_5e1d1_row15_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_5e1d1_row0_col6, #T_5e1d1_row13_col6 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_5e1d1_row0_col10, #T_5e1d1_row1_col10, #T_5e1d1_row3_col10, #T_5e1d1_row5_col11, #T_5e1d1_row7_col3, #T_5e1d1_row8_col0, #T_5e1d1_row9_col3, #T_5e1d1_row11_col13, #T_5e1d1_row13_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_5e1d1_row0_col11, #T_5e1d1_row2_col4, #T_5e1d1_row3_col4, #T_5e1d1_row11_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_5e1d1_row0_col12, #T_5e1d1_row11_col12 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_5e1d1_row0_col13, #T_5e1d1_row2_col0, #T_5e1d1_row6_col13, #T_5e1d1_row7_col13, #T_5e1d1_row10_col3, #T_5e1d1_row12_col3, #T_5e1d1_row15_col13 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_5e1d1_row0_col14, #T_5e1d1_row0_col15, #T_5e1d1_row1_col6, #T_5e1d1_row1_col14, #T_5e1d1_row1_col15, #T_5e1d1_row6_col12, #T_5e1d1_row9_col15, #T_5e1d1_row13_col15 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_5e1d1_row1_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_5e1d1_row1_col3, #T_5e1d1_row3_col13, #T_5e1d1_row4_col0, #T_5e1d1_row4_col7, #T_5e1d1_row4_col13, #T_5e1d1_row5_col2, #T_5e1d1_row5_col13, #T_5e1d1_row6_col3, #T_5e1d1_row9_col0, #T_5e1d1_row10_col6, #T_5e1d1_row10_col8, #T_5e1d1_row11_col3, #T_5e1d1_row11_col5, #T_5e1d1_row13_col3, #T_5e1d1_row13_col7, #T_5e1d1_row14_col3, #T_5e1d1_row14_col10 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_5e1d1_row1_col4, #T_5e1d1_row2_col13, #T_5e1d1_row13_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_5e1d1_row1_col5, #T_5e1d1_row4_col8, #T_5e1d1_row5_col7, #T_5e1d1_row7_col5, #T_5e1d1_row13_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_5e1d1_row1_col7, #T_5e1d1_row12_col7 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_5e1d1_row1_col8, #T_5e1d1_row4_col1, #T_5e1d1_row12_col8 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_5e1d1_row1_col9 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_5e1d1_row1_col11, #T_5e1d1_row9_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_5e1d1_row1_col12, #T_5e1d1_row12_col1 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_5e1d1_row1_col13, #T_5e1d1_row2_col5, #T_5e1d1_row6_col5, #T_5e1d1_row13_col5, #T_5e1d1_row14_col2 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_5e1d1_row2_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_5e1d1_row2_col6 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_5e1d1_row2_col7, #T_5e1d1_row8_col14, #T_5e1d1_row13_col14 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_5e1d1_row2_col8, #T_5e1d1_row8_col2 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_5e1d1_row2_col9 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_5e1d1_row2_col10, #T_5e1d1_row10_col9, #T_5e1d1_row15_col10 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_5e1d1_row2_col11 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_5e1d1_row2_col12 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_5e1d1_row2_col14, #T_5e1d1_row4_col14 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_5e1d1_row2_col15, #T_5e1d1_row3_col15, #T_5e1d1_row5_col15, #T_5e1d1_row8_col15, #T_5e1d1_row10_col15, #T_5e1d1_row12_col14, #T_5e1d1_row12_col15 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_5e1d1_row3_col0, #T_5e1d1_row8_col13, #T_5e1d1_row10_col2, #T_5e1d1_row10_col5, #T_5e1d1_row13_col8, #T_5e1d1_row14_col5, #T_5e1d1_row14_col11, #T_5e1d1_row15_col2, #T_5e1d1_row15_col3, #T_5e1d1_row15_col7, #T_5e1d1_row15_col8 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_5e1d1_row3_col1, #T_5e1d1_row5_col9, #T_5e1d1_row5_col12, #T_5e1d1_row10_col7, #T_5e1d1_row12_col13, #T_5e1d1_row14_col12, #T_5e1d1_row15_col12 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_5e1d1_row3_col5, #T_5e1d1_row7_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_5e1d1_row3_col6, #T_5e1d1_row5_col6 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_5e1d1_row3_col7, #T_5e1d1_row3_col11, #T_5e1d1_row5_col1, #T_5e1d1_row8_col10, #T_5e1d1_row11_col4, #T_5e1d1_row14_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_5e1d1_row3_col9, #T_5e1d1_row6_col4, #T_5e1d1_row11_col0 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_5e1d1_row3_col12, #T_5e1d1_row7_col0, #T_5e1d1_row7_col4, #T_5e1d1_row15_col9 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_5e1d1_row3_col14 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_5e1d1_row4_col2, #T_5e1d1_row4_col3 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_5e1d1_row4_col5, #T_5e1d1_row11_col7 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_5e1d1_row4_col6 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_5e1d1_row4_col10, #T_5e1d1_row5_col10 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_5e1d1_row4_col11 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_5e1d1_row4_col12, #T_5e1d1_row9_col1, #T_5e1d1_row12_col4 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_5e1d1_row4_col15, #T_5e1d1_row5_col14, #T_5e1d1_row6_col15, #T_5e1d1_row7_col15 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_5e1d1_row5_col3 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_5e1d1_row5_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_5e1d1_row6_col1 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_5e1d1_row6_col2 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_5e1d1_row6_col7 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_5e1d1_row6_col8 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_5e1d1_row6_col9 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_5e1d1_row6_col10, #T_5e1d1_row7_col10, #T_5e1d1_row9_col10, #T_5e1d1_row13_col12, #T_5e1d1_row15_col11 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_5e1d1_row6_col11 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_5e1d1_row6_col14 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_5e1d1_row7_col2, #T_5e1d1_row7_col14, #T_5e1d1_row11_col1, #T_5e1d1_row11_col14, #T_5e1d1_row12_col6 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_5e1d1_row7_col6 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_5e1d1_row7_col8, #T_5e1d1_row9_col11, #T_5e1d1_row11_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_5e1d1_row7_col9 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_5e1d1_row7_col11, #T_5e1d1_row8_col11 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_5e1d1_row7_col12, #T_5e1d1_row11_col6, #T_5e1d1_row11_col9 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_5e1d1_row8_col1 {
#   background-color: #cccfe5;

# %%
plt.figure(figsize=(15,10))

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(df_mod_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(df_mod_corr,
            annot=True,         # 실제 값을 표시한다
            mask=mask,          # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,      # 경계면 실선으로 구분하기
            cmap='coolwarm')

plt.title("Heatmap for Correlation Coefficient with Numeric Columns", fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# ## TASK 2: 컬럼 분석 노트
# - `customer_city`: 구매 고객의 소재지는 상 파울루가 가장 많았고, 그 다음이 리우 데 자네이루이다.
#     - 대도시 위주로 구매가 많이 발생했다 → 나머지 도시들도 대도시이지만, 상파울루 및 리우에 대다수 분포
# - `payment_type`: credit card로 결제한 고객이 압도적으로 많고, 약 25%가 boleto를 사용한다 (브라질 특유의 결제 수단)
# - `category_counts`
#     - 다양한 분야의 카테고리들이 판매되었다 (종합 쇼핑몰)
#         - cama_mesa_banho (bed_bath_table)
#         - beleza_saude (health_beauty)
#         - esporte_lazer(sports_leisure)
#         - moveis_decoracao (furniture_deco)
#         - informatica_acessorios (computers_accessories)

# %% [markdown]
# ## Week 3) TASK 1. 이상치 처리

# %%
df_mod.head(3)
# 수치형 변수 목록 확인
numeric_cols = df_mod.select_dtypes(include="number").columns

# 수치형 변수 목록에서, customer_zip_code_prefix, order_item_id는 제거한다 (수치형 변수가 아니다)
remove_numerics_cols =  {'customer_zip_code_prefix', 'order_item_id'}
numeric_cols = [i for i in numeric_cols if i not in remove_numerics_cols]
numeric_cols
# Out:
# ['price',
#  'freight_value',
#  'product_name_lenght',
#  'product_description_lenght',
#  'product_photos_qty',
#  'product_weight_g',
#  'product_length_cm',
#  'product_height_cm',
#  'product_width_cm',
#  'payment_sequential',
#  'payment_installments',
#  'payment_value',
#  'purchased_year',
#  'purchased_month']

# %%
# product_category_name별로 price 합계를 계산
price_sum_by_category = df_mod.groupby('product_category_name')['price'].sum()

# price 합계 기준 내림차순 정렬 후 상위 5개 범주 선택 및 합산
top_price_sum = price_sum_by_category.sort_values(ascending=False).head(5).sum()

# 전체 데이터의 price 합계 계산
total_price = df_mod['price'].sum()

# 비율 계산 (percentage)
ratio = (top_price_sum / total_price) * 100

print(f"상위 5개 범주의 price 합계가 전체 price 합계에서 차지하는 비율: {ratio:.2f}%")
# Out:
# 상위 5개 범주의 price 합계가 전체 price 합계에서 차지하는 비율: 40.15%

# %%
df_mod["product_category_name"].nunique()
# Out:
# 73

# %%
# product_category_name별로 price 합계를 계산
price_sum_by_category = df_mod.groupby('product_category_name')['price'].sum()

# price 합계 기준 내림차순 정렬 후 상위 5개 범주 선택 및 합산
top_price_sum = price_sum_by_category.sort_values(ascending=False).head(20).sum()

# 전체 데이터의 price 합계 계산
total_price = df_mod['price'].sum()

# 비율 계산 (percentage)
ratio = (top_price_sum / total_price) * 100

print(f"상위 20개 범주의 price 합계가 전체 price 합계에서 차지하는 비율: {ratio:.2f}%")
# Out:
# 상위 20개 범주의 price 합계가 전체 price 합계에서 차지하는 비율: 85.11%

# %%
print("판매 상위 20개 브랜드인 데이터가 전체에서 차지하는 비율:", df_mod[df_mod["product_category_name"].isin(price_sum_by_category.sort_values(ascending=False).head(20).keys())].shape[0]/df_mod.shape[0] * 100)
# Out:
# 판매 상위 20개 브랜드인 데이터가 전체에서 차지하는 비율: 84.45012787723786

# %%
# product_category_name별로 price 합계를 계산한 후, 상위 20개 범주 선택
top_categories = df_mod.groupby('product_category_name')['price'].sum().sort_values(ascending=False).head(20).index
df_top = df_mod[df_mod['product_category_name'].isin(top_categories)]

# subplot 생성
nrows, ncols = 4, 3
fig, axes = plt.subplots(nrows, ncols, figsize=(20, 20))

# axes를 1차원 array로 펴기 (transpose 후 flatten)
axes = axes.T.flatten()

# 각 numeric column에 대해 boxplot 그리기
for col, ax in zip(numeric_cols, axes):
    sns.boxplot(data=df_top, x=col, y="product_category_name", ax=ax)
    # 필요 시 추가 플롯 설정 가능 (예: sns.stripplot)

plt.suptitle("Boxplot for Numeric Columns by Product Category Type", fontsize=16, fontweight='bold', y=0.995)
fig.tight_layout()
plt.show()

# %% [markdown]
# - e-commerce 쇼핑몰의 상품 카테고리가 다양하기 때문에, 수치형 변수 값의 범위는 다양할 것
#     - `boxplot`을 그렸을 때 이상치처럼 보이긴 하지만, 일단 전부 있을 법한 데이터라고 생각하고 별도의 이상치 처리 skip

# %%
# 하나의 transaction_id에서 여러 활동 이루어진 것 확인
df_mod["order_id"].value_counts()
# Out:
# order_id
# 895ab968e7bb0d5659d16cd74cd1650c    63
# fedcd9f7ccdc8cba3a18defedd1a5547    38
# ccf804e764ed5650cd8759557269dc13    26
# 68986e4324f6a21481df4e6e89abcf01    24
# a3725dfe487d359b5be08cac48b64ec5    24
#                                     ..
# 878a17cea3ed0bda2fb9726c2d4ad57c     1
# af099467911b979b79b3a49231876086     1
# 3a2012438f0919dc24e43b9e8b21c4f1     1
# 3f2502be2cb245c8c7ca170ddf39465b     1
# 66dea50a8b16d9b4dee7af250b4be1a5     1
# Name: count, Length: 95128, dtype: int64

# %%
df_mod[df_mod["order_id"]=="895ab968e7bb0d5659d16cd74cd1650c"]
# Out:
#                                order_id                       customer_id  \
# 84420  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# 84421  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# 84422  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# 84423  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# 84424  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# ...                                 ...                               ...
# 84478  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# 84479  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# 84480  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# 84481  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# 84482  895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 84420    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
# 84421    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
# 84422    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
# 84423    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
# 84424    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
# ...            ...                      ...                  ...
# 84478    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
# 84479    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
# 84480    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
# 84481    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
# 84482    delivered      2017-08-08 20:26:31  2017-08-08 20:43:31
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 84420          2017-08-10 11:58:14           2017-08-14 12:46:18
# 84421          2017-08-10 11:58:14           2017-08-14 12:46:18
# 84422          2017-08-10 11:58:14           2017-08-14 12:46:18
# 84423          2017-08-10 11:58:14           2017-08-14 12:46:18
# 84424          2017-08-10 11:58:14           2017-08-14 12:46:18
# ...                            ...                           ...
# 84478          2017-08-10 11:58:14           2017-08-14 12:46:18
# 84479          2017-08-10 11:58:14           2017-08-14 12:46:18
# 84480          2017-08-10 11:58:14           2017-08-14 12:46:18
# 84481          2017-08-10 11:58:14           2017-08-14 12:46:18
# 84482          2017-08-10 11:58:14           2017-08-14 12:46:18
#
#       order_estimated_delivery_date  order_item_id  \
# 84420           2017-08-30 00:00:00              1
# 84421           2017-08-30 00:00:00              1
# 84422           2017-08-30 00:00:00              1
# 84423           2017-08-30 00:00:00              1
# 84424           2017-08-30 00:00:00              1
# ...                             ...            ...
# 84478           2017-08-30 00:00:00              3
# 84479           2017-08-30 00:00:00              3
# 84480           2017-08-30 00:00:00              3
# 84481           2017-08-30 00:00:00              3
# 84482           2017-08-30 00:00:00              3
#
#                              product_id                         seller_id  \
# 84420  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84421  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84422  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84423  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# 84424  ebf9bc6cd600eadd681384e3116fda85  822166ed1e47908f7cfb49946d03c726
# ...                                 ...                               ...
# 84478  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84479  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84480  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84481  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
# 84482  5ddab10d5e0a23acb99acf56b62b3276  3d0cd21d41671c46f82cd11176bf7277
#
#        shipping_limit_date  price  freight_value  product_category_name  \
# 84420  2017-08-14 20:43:31  12.99          23.21        cama_mesa_banho
# 84421  2017-08-14 20:43:31  12.99          23.21        cama_mesa_banho
# 84422  2017-08-14 20:43:31  12.99          23.21        cama_mesa_banho
# 84423  2017-08-14 20:43:31  12.99          23.21        cama_mesa_banho
# 84424  2017-08-14 20:43:31  12.99          23.21        cama_mesa_banho
# ...                    ...    ...            ...                    ...
# 84478  2017-08-14 20:43:31  83.80           5.12  utilidades_domesticas
# 84479  2017-08-14 20:43:31  83.80           5.12  utilidades_domesticas
# 84480  2017-08-14 20:43:31  83.80           5.12  utilidades_domesticas
# 84481  2017-08-14 20:43:31  83.80           5.12  utilidades_domesticas
# 84482  2017-08-14 20:43:31  83.80           5.12  utilidades_domesticas
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 84420                 37.0                        86.0                 2.0
# 84421                 37.0                        86.0                 2.0
# 84422                 37.0                        86.0                 2.0
# 84423                 37.0                        86.0                 2.0
# 84424                 37.0                        86.0                 2.0
# ...                    ...                         ...                 ...
# 84478                 56.0                       548.0                 8.0
# 84479                 56.0                       548.0                 8.0
# 84480                 56.0                       548.0                 8.0
# 84481                 56.0                       548.0                 8.0
# 84482                 56.0                       548.0                 8.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 84420            1300.0               50.0                9.0
# 84421            1300.0               50.0                9.0
# 84422            1300.0               50.0                9.0
# 84423            1300.0               50.0                9.0
# 84424            1300.0               50.0                9.0
# ...                 ...                ...                ...
# 84478             450.0               30.0               20.0
# 84479             450.0               30.0               20.0
# 84480             450.0               30.0               20.0
# 84481             450.0               30.0               20.0
# 84482             450.0               30.0               20.0
#
#        product_width_cm  payment_sequential payment_type  \
# 84420              41.0                  17      voucher
# 84421              41.0                   1      voucher
# 84422              41.0                  13      voucher
# 84423              41.0                  16      voucher
# 84424              41.0                  19      voucher
# ...                 ...                 ...          ...
# 84478              11.0                  15      voucher
# 84479              11.0                  20      voucher
# 84480              11.0                  14      voucher
# 84481              11.0                   9      voucher
# 84482              11.0                   6      voucher
#
#        payment_installments  payment_value                customer_unique_id  \
# 84420                     1          16.70  9a736b248f67d166d2fbb006bcb877c3
# 84421                     1           2.61  9a736b248f67d166d2fbb006bcb877c3
# 84422                     1          16.70  9a736b248f67d166d2fbb006bcb877c3
# 84423                     1          16.70  9a736b248f67d166d2fbb006bcb877c3
# 84424                     1           0.24  9a736b248f67d166d2fbb006bcb877c3
# ...                     ...            ...                               ...
# 84478                     1          16.70  9a736b248f67d166d2fbb006bcb877c3
# 84479                     1           4.61  9a736b248f67d166d2fbb006bcb877c3
# 84480                     1          16.70  9a736b248f67d166d2fbb006bcb877c3
# 84481                     1           2.61  9a736b248f67d166d2fbb006bcb877c3
# 84482                     1           2.61  9a736b248f67d166d2fbb006bcb877c3
#
#        customer_zip_code_prefix customer_city customer_state  purchased_year  \
# 84420                      3227     sao paulo             SP            2017
# 84421                      3227     sao paulo             SP            2017
# 84422                      3227     sao paulo             SP            2017
# 84423                      3227     sao paulo             SP            2017
# 84424                      3227     sao paulo             SP            2017
# ...                         ...           ...            ...             ...
# 84478                      3227     sao paulo             SP            2017
# 84479                      3227     sao paulo             SP            2017
# 84480                      3227     sao paulo             SP            2017
# 84481                      3227     sao paulo             SP            2017
# 84482                      3227     sao paulo             SP            2017
#
#        purchased_month
# 84420                8
# 84421                8
# 84422                8
# 84423                8
# 84424                8
# ...                ...
# 84478                8
# 84479                8
# 84480                8
# 84481                8
# 84482                8
#
# [63 rows x 32 columns]

# %% [markdown]
# ## Week 3) Task 2. Feature Engineering

# %% [markdown]
# - 날짜 파생 컬럼 생성
#     - `order_purchase_timestamp` 컬럼을 년, 월, 일, 시간으로 나눈다

# %%
# pd.to_datetime으로 order_purchase_timestamp 컬럼을 datetime type으로 변경
df_mod['order_purchase_timestamp'] = pd.to_datetime(df_mod['order_purchase_timestamp'])

# 연, 월, 일, 시간 추출
df_mod['order_purchase_year'] = df_mod['order_purchase_timestamp'].dt.year
df_mod['order_purchase_month'] = df_mod['order_purchase_timestamp'].dt.month
df_mod['order_purchase_day'] = df_mod['order_purchase_timestamp'].dt.day
df_mod['order_purchase_hour'] = df_mod['order_purchase_timestamp'].dt.hour

# 요일  (영어로 요일 표기, ex: Monday, Tuesday, ...)
df_mod['order_purchase_dayofweek'] = df_mod['order_purchase_timestamp'].dt.day_name()

# %%
# order_purchase_month에 대해 season 컬럼 생성 (3개월 단위: 봄, 여름, 가을, 겨울)
def month_to_season(m):
    if m in [3, 4, 5]:
        return 'Spring'  # 봄
    elif m in [6, 7, 8]:
        return 'Summer'  # 여름
    elif m in [9, 10, 11]:
        return 'Fall'    # 가을
    else:
        return 'Winter'  # 겨울

df_mod['season'] = df_mod['order_purchase_month'].apply(month_to_season)

# order_purchase_day에 대해 day_type 컬럼 생성
# 요일 정보(order_purchase_dayofweek)를 사용하여 주말(Saturday, Sunday)은 Weekend, 나머지는 Weekday로 분류
df_mod['day_type'] = df_mod['order_purchase_dayofweek'].apply(lambda x: 'Weekend' if x in ['Saturday', 'Sunday'] else 'Weekday')

# order_purchase_hour에 대해 hour_type 컬럼 생성
# 7시부터 18시는 "Day", 그 외는 "Night"으로 분류
def hour_to_type(h):
    return 'Day' if 7 <= h <= 18 else 'Night'

df_mod['hour_type'] = df_mod['order_purchase_hour'].apply(hour_to_type)

# order_purchase_dayofweek에 대해서도 dayofweek_type 컬럼 생성 (주말/주중)
df_mod['dayofweek_type'] = df_mod['order_purchase_dayofweek'].apply(lambda x: 'Weekend' if x in ['Saturday', 'Sunday'] else 'Weekday')

# %%
# 파생 컬럼 확인
df_mod[['order_purchase_year', 'order_purchase_month', 'order_purchase_day', 'order_purchase_hour', 'order_purchase_dayofweek', 'season', 'day_type', 'hour_type', 'dayofweek_type']].head(3)
# Out:
#    order_purchase_year  order_purchase_month  order_purchase_day  \
# 0                 2017                    10                   2
# 1                 2017                    10                   2
# 2                 2017                    10                   2
#
#    order_purchase_hour order_purchase_dayofweek season day_type hour_type  \
# 0                   10                   Monday   Fall  Weekday       Day
# 1                   10                   Monday   Fall  Weekday       Day
# 2                   10                   Monday   Fall  Weekday       Day
#
#   dayofweek_type
# 0        Weekday
# 1        Weekday
# 2        Weekday

# %%
# order_purchase_dayofweek의 x축 순서를 월요일부터 일요일로 지정
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# 각 subplot에 사용할 hue 지정 매핑
hue_mapping = {
    'order_purchase_year': None,           # hue 없음
    'order_purchase_month': 'season',        # season 컬럼 사용
    'order_purchase_day': 'day_type',        # day_type 컬럼 사용
    'order_purchase_hour': 'hour_type',      # hour_type 컬럼 사용
    'order_purchase_dayofweek': 'dayofweek_type'  # dayofweek_type 컬럼 사용
}

# Subplot 생성 (5행 1열)
nrows, ncols = 5, 1
fig, axes = plt.subplots(nrows, ncols, figsize=(20, 20))
axes = axes.T.flatten()  # transpose 후 flatten하여 1차원 배열로 만듦

# 6. 각 컬럼에 대해 countplot 그리기
for col, ax in zip(['order_purchase_year', 'order_purchase_month', 'order_purchase_day', 'order_purchase_hour', 'order_purchase_dayofweek'], axes):
    hue = hue_mapping.get(col)
    # order_purchase_dayofweek의 경우 x축 순서를 days_order로 지정
    if col == 'order_purchase_dayofweek':
        sns.countplot(data=df_mod, x=col, ax=ax, hue=hue, order=days_order)
    else:
        if hue:
            sns.countplot(data=df_mod, x=col, ax=ax, hue=hue)
        else:
            sns.countplot(data=df_mod, x=col, ax=ax)
    ax.set_title(col)  # 각 subplot에 제목 추가

plt.suptitle("Countplot for Numeric Columns with Hue Categories", fontsize=16, fontweight='bold', y=0.995)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 일자에 따른 배송완료된 주문 분석

# %%
df_mod.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
#
#   order_estimated_delivery_date  order_item_id  \
# 0           2017-10-18 00:00:00              1
# 1           2017-10-18 00:00:00              1
# 2           2017-10-18 00:00:00              1
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 2  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
#
#    shipping_limit_date  price  freight_value  product_category_name  \
# 0  2017-10-06 11:07:15  29.99           8.72  utilidades_domesticas
# 1  2017-10-06 11:07:15  29.99           8.72  utilidades_domesticas
# 2  2017-10-06 11:07:15  29.99           8.72  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       268.0                 4.0
# 1                 40.0                       268.0                 4.0
# 2                 40.0                       268.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             500.0               19.0                8.0              13.0
# 1             500.0               19.0                8.0              13.0
# 2             500.0               19.0                8.0              13.0
#
#    payment_sequential payment_type  payment_installments  payment_value  \
# 0                   1  credit_card                     1          18.12
# 1                   3      voucher                     1           2.00
# 2                   2      voucher                     1          18.59
#
#                  customer_unique_id  customer_zip_code_prefix customer_city  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 1  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 2  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
#
#   customer_state  purchased_year  purchased_month  order_purchase_year  \
# 0             SP            2017               10                 2017
# 1             SP            2017               10                 2017
# 2             SP            2017               10                 2017
#
#    order_purchase_month  order_purchase_day  order_purchase_hour  \
# 0                    10                   2                   10
# 1                    10                   2                   10
# 2                    10                   2                   10
#
#   order_purchase_dayofweek season day_type hour_type dayofweek_type
# 0                   Monday   Fall  Weekday       Day        Weekday
# 1                   Monday   Fall  Weekday       Day        Weekday
# 2                   Monday   Fall  Weekday       Day        Weekday

# %%
df_mod.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                        object
# order_delivered_carrier_date             object
# order_delivered_customer_date            object
# order_estimated_delivery_date            object
# order_item_id                             int64
# product_id                               object
# seller_id                                object
# shipping_limit_date                      object
# price                                   float64
# freight_value                           float64
# product_category_name                    object
# product_name_lenght                     float64
# product_description_lenght              float64
# product_photos_qty                      float64
# product_weight_g                        float64
# product_length_cm                       float64
# product_height_cm                       float64
# product_width_cm                        float64
# payment_sequential                        int64
# payment_type                             object
# payment_installments                      int64
# payment_value                           float64
# customer_unique_id                       object
# customer_zip_code_prefix                  int64
# customer_city                            object
# customer_state                           object
# purchased_year                            int32
# purchased_month                           int32
# order_purchase_year                       int32
# order_purchase_month                      int32
# order_purchase_day                        int32
# order_purchase_hour                       int32
# order_purchase_dayofweek                 object
# season                                   object
# day_type                                 object
# hour_type                                object
# dayofweek_type                           object
# dtype: object

# %%
df_mod.order_status.value_counts(normalize=True)
# Out:
# order_status
# delivered    0.999938
# canceled     0.000062
# Name: proportion, dtype: float64

# %%
delivered_df = df_mod[df_mod["order_status"]=="delivered"]
delivered_df["order_purchase_timestamp_ymd"] = delivered_df['order_purchase_timestamp'].dt.date
delivered_gr = delivered_df.groupby(["order_purchase_timestamp_ymd", "hour_type"])["price"].sum().reset_index()

# %%
delivered_gr
# Out:
#      order_purchase_timestamp_ymd hour_type    price
# 0                      2016-10-03       Day    51.80
# 1                      2016-10-03     Night   390.18
# 2                      2016-10-04       Day  5062.04
# 3                      2016-10-04     Night  4031.16
# 4                      2016-10-05       Day  4964.21
# ...                           ...       ...      ...
# 1215                   2018-08-27       Day  3457.18
# 1216                   2018-08-27     Night  1931.49
# 1217                   2018-08-28       Day  2102.17
# 1218                   2018-08-28     Night  1655.34
# 1219                   2018-08-29       Day  1546.04
#
# [1220 rows x 3 columns]

# %%
import matplotlib.dates as mdates

# Calculate the mean price value
mean_price = delivered_gr['price'].mean()

plt.figure(figsize=(15, 7))

# Create line plot with hue based on "hour_type"
sns.lineplot(x="order_purchase_timestamp_ymd", y="price", 
             hue="hour_type",
             data=delivered_gr)

# Draw a red horizontal line at the mean price value
plt.axhline(y=mean_price, color='red', linestyle='--', label=f'Mean Price ({mean_price:.2f})')

# Set x-axis locator to show labels every 6 months
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Set the title and axis labels with specified font sizes
plt.title('Total Purchased Price by Date & Time', fontsize=16)
plt.xlabel('Purchased Date', fontsize=14)
plt.ylabel('Total Price', fontsize=14)

# Display the legend to show the mean price label
plt.legend()

plt.tight_layout()
plt.show()

# %%
order_counts= (df_mod.order_delivered_customer_date <= df_mod.order_estimated_delivery_date)
order_counts = order_counts.value_counts()
labels = ['On Time' if val else 'Late' for val in order_counts.index]

# %%
plt.figure(figsize=(10, 5))
_, _, autotexts = plt.pie(order_counts, labels=labels, autopct='%1.1f%%', startangle=90, counterclock=False)
for autotext in autotexts:
    autotext.set_color('white')
    
plt.title('Proportion of On-Time Deliveries')

plt.show()

# %% [markdown]
# ## 코호트

# %%
orders = pd.read_csv('../data/olist_orders_dataset.csv')
payments = pd.read_csv('../data/olist_order_payments_dataset.csv')

# %%
orders['order_delivered_carrier_date'] = pd.to_datetime(orders['order_delivered_carrier_date']) # datetime conversion
payments = payments.set_index('order_id') 
orders = orders.set_index('order_id') 

joined = orders.join(payments)

# %%
joined.head(3)
# Out:
#                                                        customer_id  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#                                  order_status order_purchase_timestamp  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
#
#                                     order_approved_at  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7  2017-10-02 11:07:15
# e481f51cbdc54678b7cc49136f2d6af7  2017-10-02 11:07:15
# e481f51cbdc54678b7cc49136f2d6af7  2017-10-02 11:07:15
#
#                                  order_delivered_carrier_date  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7          2017-10-04 19:55:00
# e481f51cbdc54678b7cc49136f2d6af7          2017-10-04 19:55:00
# e481f51cbdc54678b7cc49136f2d6af7          2017-10-04 19:55:00
#
#                                  order_delivered_customer_date  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7           2017-10-10 21:25:13
# e481f51cbdc54678b7cc49136f2d6af7           2017-10-10 21:25:13
# e481f51cbdc54678b7cc49136f2d6af7           2017-10-10 21:25:13
#
#                                  order_estimated_delivery_date  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7           2017-10-18 00:00:00
# e481f51cbdc54678b7cc49136f2d6af7           2017-10-18 00:00:00
# e481f51cbdc54678b7cc49136f2d6af7           2017-10-18 00:00:00
#
#                                   payment_sequential payment_type  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7                 1.0  credit_card
# e481f51cbdc54678b7cc49136f2d6af7                 3.0      voucher
# e481f51cbdc54678b7cc49136f2d6af7                 2.0      voucher
#
#                                   payment_installments  payment_value
# order_id
# e481f51cbdc54678b7cc49136f2d6af7                   1.0          18.12
# e481f51cbdc54678b7cc49136f2d6af7                   1.0           2.00
# e481f51cbdc54678b7cc49136f2d6af7                   1.0          18.59

# %%
# pd.to_datetime으로 order_purchase_timestamp 컬럼을 datetime type으로 변경
joined['order_purchase_timestamp'] = pd.to_datetime(joined['order_purchase_timestamp'])

# 연, 월, 일, 시간 추출
joined['order_purchase_year'] = joined['order_purchase_timestamp'].dt.year
joined['order_purchase_month'] = joined['order_purchase_timestamp'].dt.month
joined['order_purchase_day'] = joined['order_purchase_timestamp'].dt.day
joined['order_purchase_hour'] = joined['order_purchase_timestamp'].dt.hour

# 요일  (영어로 요일 표기, ex: Monday, Tuesday, ...)
joined['order_purchase_dayofweek'] = joined['order_purchase_timestamp'].dt.day_name()

# %%
# order_purchase_month에 대해 season 컬럼 생성 (3개월 단위: 봄, 여름, 가을, 겨울)
def month_to_season(m):
    if m in [3, 4, 5]:
        return 'Spring'  # 봄
    elif m in [6, 7, 8]:
        return 'Summer'  # 여름
    elif m in [9, 10, 11]:
        return 'Fall'    # 가을
    else:
        return 'Winter'  # 겨울

joined['season'] = joined['order_purchase_month'].apply(month_to_season)

# order_purchase_day에 대해 day_type 컬럼 생성
# 요일 정보(order_purchase_dayofweek)를 사용하여 주말(Saturday, Sunday)은 Weekend, 나머지는 Weekday로 분류
joined['day_type'] = joined['order_purchase_dayofweek'].apply(lambda x: 'Weekend' if x in ['Saturday', 'Sunday'] else 'Weekday')

# order_purchase_hour에 대해 hour_type 컬럼 생성
# 7시부터 18시는 "Day", 그 외는 "Night"으로 분류
def hour_to_type(h):
    return 'Day' if 7 <= h <= 18 else 'Night'

joined['hour_type'] = joined['order_purchase_hour'].apply(hour_to_type)

# order_purchase_dayofweek에 대해서도 dayofweek_type 컬럼 생성 (주말/주중)
joined['dayofweek_type'] = joined['order_purchase_dayofweek'].apply(lambda x: 'Weekend' if x in ['Saturday', 'Sunday'] else 'Weekday')

# %%
success_order = joined[joined["order_status"] == "delivered"]

success_2017 = success_order[success_order["order_purchase_year"]==2017]

# %%
def cohort_retention(df, id_col="cust_id", month_col="month"):
    # 코호트 분석을 위해, cust_id별로 첫 구매한 달을 뽑아 first_month (코호트) 컬럼에 선언
    df["first_month"] = df.groupby(id_col)[month_col].transform("min")

    # 첫 구매 후 다음 구매까지 걸린 경과 월 수 계산
    df["month_diff"] = df[month_col] - df["first_month"]

    # 첫 구매 후 다음 구매까지 걸린 시간(월) groupby하여 cust_id 갯수 파악
    cohort_data = df.groupby(["first_month", "month_diff"])[id_col].nunique().reset_index()

    # 각 코호트의 고객 수 계산
    cohort_sizes = df.groupby(["first_month"])[id_col].nunique()

    # 경과 월 별 구매 유지율 계산
    cohort_data = cohort_data.merge(cohort_sizes, on="first_month")
    cohort_data["retention"] = cohort_data[f"{id_col}_x"] / cohort_data[f"{id_col}_y"]

    # heatmap을 그리기 위해, pivot_table 사용
    cohort_pivot = cohort_data.pivot_table(index="first_month", columns="month_diff", values="retention")
    return cohort_pivot

# %%
cohort_pivot = cohort_retention(success_2017, "customer_id", "order_purchase_month")

# %%
plt.figure(figsize=(20, 10))
plt.title("2013년 코호트 및 경과 월별 구매 유지율 (Retention)")
sns.heatmap(cohort_pivot, cmap="Reds", annot=True, fmt=".1%")
plt.show()
