# %% [markdown]
# # Brazilian E-Commerce Public Dataset by Olist

# %%
import numpy as np
import pandas as pd
from unidecode import unidecode

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("ticks")
# %matplotlib inline

import os

from datetime import datetime
from datetime import timedelta
import missingno as msno

import warnings
warnings.filterwarnings(action='ignore')

pd.set_option("display.max_columns", None)

plt.rc('font', family='Noto Sans')
plt.rcParams['axes.unicode_minus'] = False

# %%
# 데이터 불러오기
file_path = "../data/total_merged.csv"
df = pd.read_csv(file_path, index_col = 0)
df.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 2           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
#
#    customer_zip_code_prefix customer_city customer_state  order_item_id  \
# 0                      3149     sao paulo             SP            1.0
# 1                      3149     sao paulo             SP            1.0
# 2                      3149     sao paulo             SP            1.0
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 2  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-10-06 11:07:15  29.99           8.72                   1  credit_card
# 1  2017-10-06 11:07:15  29.99           8.72                   3      voucher
# 2  2017-10-06 11:07:15  29.99           8.72                   2      voucher
#
#    payment_installments  payment_value  product_category_name  \
# 0                     1          18.12  utilidades_domesticas
# 1                     1           2.00  utilidades_domesticas
# 2                     1          18.59  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       268.0                 4.0
# 1                 40.0                       268.0                 4.0
# 2                 40.0                       268.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             500.0               19.0                8.0              13.0
# 1             500.0               19.0                8.0              13.0
# 2             500.0               19.0                8.0              13.0

# %% [markdown]
# ## TASK 1: EDA - 변수 간 관계 분석 및 유의미한 시각화 "5개 이상"

# %% [markdown]
# ### 1-1. 결측치 비율 시각화 및 결측치 처리
# - 결측치 비율 `10% 미만` : 제거 또는 대체
# - 결측치 비율 `10% 이상 20% 미만` : 모델 기반 처리
# - 결측치 비율 `20% 이상` : 모델 기반 처리

# %%
# 결측치 비율 구함
null_total = df.isnull().sum()
null_count = df.isnull().count()
null_pct = round((null_total/null_count)*100, 1)

# 결측치 개수, 퍼센트 데이터프레임으로 생성
missing = pd.concat([null_total, null_pct], axis=1, keys=["Total", "Percent"])
missing
# Out:
#                                Total  Percent
# order_id                           0      0.0
# customer_id                        0      0.0
# order_status                       0      0.0
# order_purchase_timestamp           0      0.0
# order_approved_at                 15      0.0
# order_delivered_carrier_date    1245      1.1
# order_delivered_customer_date   2567      2.2
# order_estimated_delivery_date      0      0.0
# customer_unique_id                 0      0.0
# customer_zip_code_prefix           0      0.0
# customer_city                      0      0.0
# customer_state                     0      0.0
# order_item_id                      0      0.0
# product_id                         0      0.0
# seller_id                          0      0.0
# shipping_limit_date                0      0.0
# price                              0      0.0
# freight_value                      0      0.0
# payment_sequential                 0      0.0
# payment_type                       0      0.0
# payment_installments               0      0.0
# payment_value                      0      0.0
# product_category_name           1698      1.4
# product_name_lenght             1698      1.4
# product_description_lenght      1698      1.4
# product_photos_qty              1698      1.4
# product_weight_g                  20      0.0
# product_length_cm                 20      0.0
# product_height_cm                 20      0.0
# product_width_cm                  20      0.0

# %%
# 결측치 비율 시각화
plt.figure(figsize=(10, 5))
sns_pct = sns.barplot(x="index", y="Percent", data=missing[missing["Total"]!=0].reset_index())
sns_pct.set_xticklabels(sns_pct.get_xticklabels(), rotation=45)

# bar 그래프 상단에 비율 (%) 표기
for bar in sns_pct.patches:
    height = bar.get_height()                   # .get_height() : y좌표

    plt.text(bar.get_x() + bar.get_width()/2,   # 퍼센트 글자 위치
             height+0.01,                        # 퍼센트 글자 높이
             "%.1f" % height,                   # 퍼센트 소수점 지정
             ha="center")                       # 가운데 정렬

# 시각화 제목 이름, 폰트 크기 지정
sns_pct.set_title("Total Missing Value (%)", fontsize=15)
plt.show()

# %% [markdown]
# 결측치가 존재하는 컬럼들의 결측치 비율이 매우 낮다 (약 1 ~ 2%) → 제거하기로 결정

# %%
# 결측치 처리 전과 처리 후 비교
print("결측치 drop 전 데이터프레임 row 수 :", df.shape[0])
print("결측치 drop 후 데이터프레임 row 수 :", df.dropna().shape[0])
print("결측치 drop 비율", round((df.shape[0]-df.dropna().shape[0])/df.shape[0], 2), "%")

# 결측치 제거
df_mod = df.dropna()
# Out:
# 결측치 drop 전 데이터프레임 row 수 : 117601
# 결측치 drop 후 데이터프레임 row 수 : 113390
# 결측치 drop 비율 0.04 %

# %% [markdown]
# ### 1-2. 주요 시각화

# %%
# 결제 날짜에서 연도만 빼온다
df_mod["purchased_year"] = pd.to_datetime(df_mod["order_purchase_timestamp"]).dt.year
df_mod["purchased_month"] = pd.to_datetime(df_mod["order_purchase_timestamp"]).dt.month

df_mod.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 2           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
#
#    customer_zip_code_prefix customer_city customer_state  order_item_id  \
# 0                      3149     sao paulo             SP            1.0
# 1                      3149     sao paulo             SP            1.0
# 2                      3149     sao paulo             SP            1.0
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 2  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
#
#    shipping_limit_date  price  freight_value  payment_sequential payment_type  \
# 0  2017-10-06 11:07:15  29.99           8.72                   1  credit_card
# 1  2017-10-06 11:07:15  29.99           8.72                   3      voucher
# 2  2017-10-06 11:07:15  29.99           8.72                   2      voucher
#
#    payment_installments  payment_value  product_category_name  \
# 0                     1          18.12  utilidades_domesticas
# 1                     1           2.00  utilidades_domesticas
# 2                     1          18.59  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       268.0                 4.0
# 1                 40.0                       268.0                 4.0
# 2                 40.0                       268.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             500.0               19.0                8.0              13.0
# 1             500.0               19.0                8.0              13.0
# 2             500.0               19.0                8.0              13.0
#
#    purchased_year  purchased_month
# 0            2017               10
# 1            2017               10
# 2            2017               10

# %%
city_counts = df_mod.groupby(["customer_city"]).count()
city_top10 = city_counts.sort_values(by="order_id", ascending=False).head(10)
city_top10
# Out:
#                        order_id  customer_id  order_status  \
# customer_city
# sao paulo                 17868        17868         17868
# rio de janeiro             7822         7822          7822
# belo horizonte             3134         3134          3134
# brasilia                   2374         2374          2374
# curitiba                   1768         1768          1768
# campinas                   1686         1686          1686
# porto alegre               1589         1589          1589
# salvador                   1435         1435          1435
# guarulhos                  1348         1348          1348
# sao bernardo do campo      1075         1075          1075
#
#                        order_purchase_timestamp  order_approved_at  \
# customer_city
# sao paulo                                 17868              17868
# rio de janeiro                             7822               7822
# belo horizonte                             3134               3134
# brasilia                                   2374               2374
# curitiba                                   1768               1768
# campinas                                   1686               1686
# porto alegre                               1589               1589
# salvador                                   1435               1435
# guarulhos                                  1348               1348
# sao bernardo do campo                      1075               1075
#
#                        order_delivered_carrier_date  \
# customer_city
# sao paulo                                     17868
# rio de janeiro                                 7822
# belo horizonte                                 3134
# brasilia                                       2374
# curitiba                                       1768
# campinas                                       1686
# porto alegre                                   1589
# salvador                                       1435
# guarulhos                                      1348
# sao bernardo do campo                          1075
#
#                        order_delivered_customer_date  \
# customer_city
# sao paulo                                      17868
# rio de janeiro                                  7822
# porto alegre                         1589              1589
# salvador                             1435              1435
# guarulhos                            1348              1348
# sao bernardo do campo                1075              1075
#
#                        product_length_cm  product_height_cm  product_width_cm  \
# customer_city
# sao paulo                          17868              17868             17868
# rio de janeiro                      7822               7822              7822
# belo horizonte                      3134               3134              3134
# brasilia                            2374               2374              2374
# curitiba                            1768               1768              1768
# campinas                            1686               1686              1686
# porto alegre                        1589               1589              1589
# salvador                            1435               1435              1435
# guarulhos                           1348               1348              1348
# sao bernardo do campo               1075               1075              1075
#
#                        purchased_year
# customer_city
# sao paulo                       17868
# rio de janeiro                   7822
# belo horizonte                   3134
# brasilia                         2374
# curitiba                         1768
# campinas                         1686
# porto alegre                     1589
# salvador                         1435
# guarulhos                        1348
# sao bernardo do campo            1075

# %%
payment_counts = df_mod.groupby("payment_type").count()
payment_counts = payment_counts.sort_values(by="order_id", ascending=False)
payment_counts
# Out:
#               order_id  customer_id  order_status  order_purchase_timestamp  \
# payment_type
# credit_card      83706        83706         83706                     83706
# boleto           22047        22047         22047                     22047
# voucher           6012         6012          6012                      6012
# debit_card        1625         1625          1625                      1625
#
#               order_approved_at  order_delivered_carrier_date  \
# payment_type
# credit_card               83706                         83706
# boleto                    22047                         22047
# voucher                    6012                          6012
# debit_card                 1625                          1625
#
#               order_delivered_customer_date  order_estimated_delivery_date  \
# payment_type
# credit_card                           83706                          83706
# boleto                                22047                          22047
# voucher                                6012                           6012
# debit_card                             1625                           1625
#
#               customer_unique_id  customer_zip_code_prefix  customer_city  \
# payment_type
# credit_card                83706                     83706          83706
# boleto                     22047                     22047          22047
# voucher                     6012                      6012           6012
# debit_card                  1625                      1625           1625
#
#               customer_state  order_item_id  product_id  seller_id  \
# payment_type
# credit_card            83706          83706       83706      83706
# boleto                 22047          22047       22047      22047
# voucher                 6012           6012        6012       6012
# debit_card              1625           1625        1625       1625
#
#               shipping_limit_date  price  freight_value  payment_sequential  \
# payment_type
# credit_card                 83706  83706          83706               83706
# boleto                      22047  22047          22047               22047
# voucher                      6012   6012           6012                6012
# debit_card                   1625   1625           1625                1625
#
#               payment_installments  payment_value  product_category_name  \
# payment_type
# credit_card                  83706          83706                  83706
# boleto                       22047          22047                  22047
# voucher                       6012           6012                   6012
# debit_card                    1625           1625                   1625
#
#               product_name_lenght  product_description_lenght  \
# payment_type
# credit_card                 83706                       83706
# boleto                      22047                       22047
# voucher                      6012                        6012
# debit_card                   1625                        1625
#
#               product_photos_qty  product_weight_g  product_length_cm  \
# payment_type
# credit_card                83706             83706              83706
# boleto                     22047             22047              22047
# voucher                     6012              6012               6012
# debit_card                  1625              1625               1625
#
#               product_height_cm  product_width_cm  purchased_year
# payment_type
# credit_card               83706             83706           83706
# boleto                    22047             22047           22047
# voucher                    6012              6012            6012
# debit_card                 1625              1625            1625

# %%
category_counts = df_mod.groupby("product_category_name").count()
category_counts = category_counts.sort_values(by="order_id", ascending=False).head(5)
category_counts
# Out:
#                         order_id  customer_id  order_status  \
# product_category_name
# cama_mesa_banho            11649        11649         11649
# beleza_saude                9761         9761          9761
# esporte_lazer               8731         8731          8731
# moveis_decoracao            8553         8553          8553
# informatica_acessorios      7897         7897          7897
#
#                         order_purchase_timestamp  order_approved_at  \
# product_category_name
# cama_mesa_banho                            11649              11649
# beleza_saude                                9761               9761
# esporte_lazer                               8731               8731
# moveis_decoracao                            8553               8553
# informatica_acessorios                      7897               7897
#
#                         order_delivered_carrier_date  \
# product_category_name
# cama_mesa_banho                                11649
# beleza_saude                                    9761
# esporte_lazer                                   8731
# moveis_decoracao                                8553
# informatica_acessorios                          7897
#
#                         order_delivered_customer_date  \
# product_category_name
# cama_mesa_banho                                 11649
# beleza_saude                                     9761
# esporte_lazer                                    8731
# moveis_decoracao                                 8553
# informatica_acessorios                           7897
#
#                         order_estimated_delivery_date  customer_unique_id  \
# product_category_name
# cama_mesa_banho                                 11649               11649
# beleza_saude                                     9761                9761
# esporte_lazer                                    8731                8731
# moveis_decoracao                                 8553                8553
# informatica_acessorios                           7897                7897
#
#                         customer_zip_code_prefix  customer_city  \
# product_category_name
# cama_mesa_banho                            11649          11649
# beleza_saude                                9761           9761
# esporte_lazer                               8731           8731
# moveis_decoracao                            8553           8553
# informatica_acessorios                      7897           7897
#
#                         customer_state  order_item_id  product_id  seller_id  \
# product_category_name
# cama_mesa_banho                  11649          11649       11649      11649
# beleza_saude                      9761           9761        9761       9761
# esporte_lazer                     8731           8731        8731       8731
# moveis_decoracao                  8553           8553        8553       8553
# informatica_acessorios            7897           7897        7897       7897
#
#                         shipping_limit_date  price  freight_value  \
# product_category_name
# cama_mesa_banho                       11649  11649          11649
# beleza_saude                           9761   9761           9761
# esporte_lazer                          8731   8731           8731
# moveis_decoracao                       8553   8553           8553
# informatica_acessorios                 7897   7897           7897
#
#                         payment_sequential  payment_type  \
# product_category_name
# cama_mesa_banho                      11649         11649
# beleza_saude                          9761          9761
# esporte_lazer                         8731          8731
# moveis_decoracao                      8553          8553
# informatica_acessorios                7897          7897
#
#                         payment_installments  payment_value  \
# product_category_name
# cama_mesa_banho                        11649          11649
# beleza_saude                            9761           9761
# esporte_lazer                           8731           8731
# moveis_decoracao                        8553           8553
# informatica_acessorios                  7897           7897
#
#                         product_name_lenght  product_description_lenght  \
# product_category_name
# cama_mesa_banho                       11649                       11649
# beleza_saude                           9761                        9761
# esporte_lazer                          8731                        8731
# moveis_decoracao                       8553                        8553
# informatica_acessorios                 7897                        7897
#
#                         product_photos_qty  product_weight_g  \
# product_category_name
# cama_mesa_banho                      11649             11649
# beleza_saude                          9761              9761
# esporte_lazer                         8731              8731
# moveis_decoracao                      8553              8553
# informatica_acessorios                7897              7897
#
#                         product_length_cm  product_height_cm  \
# product_category_name
# cama_mesa_banho                     11649              11649
# beleza_saude                         9761               9761
# esporte_lazer                        8731               8731
# moveis_decoracao                     8553               8553
# informatica_acessorios               7897               7897
#
#                         product_width_cm  purchased_year
# product_category_name
# cama_mesa_banho                    11649           11649
# beleza_saude                        9761            9761
# esporte_lazer                       8731            8731
# moveis_decoracao                    8553            8553
# informatica_acessorios              7897            7897

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
fig.suptitle('Charts for E-Commerce Data', fontsize=16, fontweight='bold')

# 첫 번째 plot
sns.barplot(data=city_top10, x="customer_city", y="customer_id", ax=axes[0, 0], hue="customer_city")
axes[0, 0].set_ylabel('Count')
axes[0, 0].set_title('Customer City')
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45)

# 두 번째 plot
sns.barplot(data=payment_counts, x="order_id", y="payment_type", ax=axes[0, 1], hue="payment_type")
axes[0, 0].set_xlabel('Count')
axes[0, 1].set_title('Payment Count')

# 세 번째 plot
wedges, texts, autotexts = axes[1, 0].pie(category_counts['order_id'], 
               labels=category_counts.index, 
               autopct="%1.1f%%", 
               startangle=90)
axes[1, 0].set_title('Purchased Category Top 5')

# 네 번째 plot
sns.lineplot(data=df_mod, x="purchased_year", y="price", hue="payment_type", marker='o', ax=axes[1, 1])
axes[1, 1].set_xticks([2016, 2017, 2018])
axes[1, 1].set_xticklabels(['2016', '2017', '2018'])
axes[1, 1].set_title('Average Price per Year')

fig.tight_layout()
plt.show()

# %% [markdown]
# ### 1-3. 상관 관계 확인

# %%
num_cols = df_mod.select_dtypes(include="number").columns.tolist()
df_mod_corr = round(df_mod[num_cols].corr(), 2)

df_mod_corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_b1bc2_row0_col0, #T_b1bc2_row1_col1, #T_b1bc2_row2_col2, #T_b1bc2_row3_col3, #T_b1bc2_row4_col4, #T_b1bc2_row5_col5, #T_b1bc2_row6_col6, #T_b1bc2_row7_col7, #T_b1bc2_row8_col8, #T_b1bc2_row9_col9, #T_b1bc2_row10_col10, #T_b1bc2_row11_col11, #T_b1bc2_row12_col12, #T_b1bc2_row13_col13, #T_b1bc2_row14_col14, #T_b1bc2_row15_col15 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b1bc2_row0_col1, #T_b1bc2_row0_col4, #T_b1bc2_row0_col13, #T_b1bc2_row1_col8, #T_b1bc2_row1_col11, #T_b1bc2_row1_col12, #T_b1bc2_row1_col13, #T_b1bc2_row3_col7, #T_b1bc2_row4_col1, #T_b1bc2_row4_col2, #T_b1bc2_row4_col8, #T_b1bc2_row6_col9, #T_b1bc2_row7_col3, #T_b1bc2_row10_col1, #T_b1bc2_row13_col9, #T_b1bc2_row14_col1, #T_b1bc2_row14_col2, #T_b1bc2_row15_col1, #T_b1bc2_row15_col2, #T_b1bc2_row15_col8, #T_b1bc2_row15_col9 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_b1bc2_row0_col2, #T_b1bc2_row2_col9, #T_b1bc2_row8_col12, #T_b1bc2_row9_col11, #T_b1bc2_row11_col9 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_b1bc2_row0_col3, #T_b1bc2_row2_col8, #T_b1bc2_row3_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_b1bc2_row0_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_b1bc2_row0_col6, #T_b1bc2_row10_col4, #T_b1bc2_row11_col4, #T_b1bc2_row13_col4, #T_b1bc2_row15_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_
{
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_b1bc2_row3_col15, #T_b1bc2_row4_col15, #T_b1bc2_row6_col14, #T_b1bc2_row6_col15, #T_b1bc2_row7_col15, #T_b1bc2_row9_col15, #T_b1bc2_row12_col15 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_b1bc2_row4_col11, #T_b1bc2_row6_col0, #T_b1bc2_row7_col2, #T_b1bc2_row9_col6, #T_b1bc2_row9_col13, #T_b1bc2_row14_col6, #T_b1bc2_row15_col6 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_b1bc2_row4_col14, #T_b1bc2_row6_col5 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_b1bc2_row5_col1, #T_b1bc2_row7_col13, #T_b1bc2_row10_col8 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_b1bc2_row5_col2, #T_b1bc2_row5_col14, #T_b1bc2_row6_col10, #T_b1bc2_row11_col3, #T_b1bc2_row11_col14 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_b1bc2_row5_col3, #T_b1bc2_row11_col12, #T_b1bc2_row13_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_b1bc2_row5_col8, #T_b1bc2_row7_col5, #T_b1bc2_row7_col11, #T_b1bc2_row9_col2, #T_b1bc2_row12_col4, #T_b1bc2_row14_col8 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_b1bc2_row5_col10, #T_b1bc2_row5_col13, #T_b1bc2_row11_col6 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_b1bc2_row5_col11, #T_b1bc2_row8_col9 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_b1bc2_row5_col15 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_b1bc2_row6_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_b1bc2_row6_col3 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_b1bc2_row6_col4, #T_b1bc2_row12_col9, #T_b1bc2_row13_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_b1bc2_row6_col8, #T_b1bc2_row8_col6, #T_b1bc2_row13_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_b1bc2_row6_col13, #T_b1bc2_row13_col6 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_b1bc2_row7_col6, #T_b1bc2_row11_col1, #T_b1bc2_row11_col8, #T_b1bc2_row15_col13 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_b1bc2_row7_col9, #T_b1bc2_row11_col2 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_b1bc2_row7_col10, #T_b1bc2_row9_col10 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_b1bc2_row7_col14 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_b1bc2_row8_col3, #T_b1bc2_row8_col7 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_b1bc2_row8_col4, #T_b1bc2_row9_col4 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_b1bc2_row8_col5 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_b1bc2_row8_col10 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_b1bc2_row8_col15, #T_b1bc2_row9_col14, #T_b1bc2_row10_col15, #T_b1bc2_row11_col15 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_b1bc2_row9_col7 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_b1bc2_row9_col8 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_b1bc2_row10_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_b1bc2_row10_col3 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_b1bc2_row10_col5 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_b1

# %%
plt.figure(figsize=(15,10))

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(df_mod_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(df_mod_corr,
            annot=True,         # 실제 값을 표시한다
            mask=mask,          # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,      # 경계면 실선으로 구분하기
            cmap='coolwarm')

plt.title("Heatmap for Correlation Coefficient with Numeric Columns", fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# ## TASK 2: 컬럼 분석 노트
# - `customer_city`: 구매 고객의 소재지는 상 파울루가 가장 많았고, 그 다음이 리우 데 자네이루이다.
#     - 대도시 위주로 구매가 많이 발생했다 → 나머지 도시들도 대도시이지만, 상파울루 및 리우에 대다수 분포
# - `payment_type`: credit card로 결제한 고객이 압도적으로 많고, 약 25%가 boleto를 사용한다 (브라질 특유의 결제 수단)
# - `category_counts`
#     - 다양한 분야의 카테고리들이 판매되었다 (종합 쇼핑몰)
#         - cama_mesa_banho (bed_bath_table)
#         - beleza_saude (health_beauty)
#         - esporte_lazer(sports_leisure)
#         - moveis_decoracao (furniture_deco)
#         - informatica_acessorios (computers_accessories)
